# %%
import cinrad
from cinrad.visualize import PPI
# %matplotlib inline
file = '/home/liyuan3970/Data/radar_typhoon_liqima/base/2019-08-10/'

f1 = cinrad.io.CinradReader(file+'Z_RADR_I_Z9574_20190810010600_O_DOR_SA_CAP.bin.bz2')
f2 = cinrad.io.CinradReader(file+'Z_RADR_I_Z9577_20190810010600_O_DOR_SA_CAP.bin.bz2')
f3 = cinrad.io.CinradReader(file+'Z_RADR_I_Z9580_20190810010600_O_DOR_SA_CAP.bin.bz2')
# rl = list(f.iter_tilt(230, 'REF'))

v1 = f1.get_data(0,230, 'REF')
v2 = f2.get_data(0, 230, 'REF')
v3 = f3.get_data(0, 230, 'REF')
v = []
v.append(v1)
v.append(v2)
v.append(v3)
f =cinrad.easycalc.GridMapper(v)

# 0.001是颗粒度，一般0.01就可以了
grid = f(0.01)
print(type(grid))

# type(f)
fig = PPI(grid)
# Out:
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/easycalc.py:407: RuntimeWarning: divide by zero encountered in true_divide
#   return np.ma.average(inp, weights=1 / wgt, axis=2)
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/numpy/ma/extras.py:605: RuntimeWarning: invalid value encountered in multiply
#   wgt = wgt*(~a.mask)
# <class 'cinrad.datastruct.Grid'>
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import cinrad
from cinrad.visualize import PPI
# %matplotlib inline
file = '/home/liyuan3970/Data/radar_typhoon_liqima/base/2019-08-10/'

f1 = cinrad.io.CinradReader(file+'Z_RADR_I_Z9574_20190810010600_O_DOR_SA_CAP.bin.bz2')
f2 = cinrad.io.CinradReader(file+'Z_RADR_I_Z9572_20190810010400_O_DOR_SA_CAP.bin.bz2')
f3 = cinrad.io.CinradReader(file+'Z_RADR_I_Z9580_20190810010600_O_DOR_SA_CAP.bin.bz2')
# rl = list(f.iter_tilt(230, 'REF'))

v1 = f1.get_data(0,230, 'REF')
v2 = f2.get_data(0, 230, 'REF')
v3 = f3.get_data(0, 230, 'REF')
v = []
v.append(v1)
v.append(v2)
v.append(v3)
f =cinrad.easycalc.GridMapper(v)

# 0.001是颗粒度，一般0.01就可以了
grid = f(0.01)
print(type(grid))

# type(f)
fig = PPI(grid)
# Out:
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.4.2-py3.7-linux-x86_64.egg/cinrad/easycalc.py:407: RuntimeWarning: divide by zero encountered in true_divide
#   return np.ma.average(inp, weights=1 / wgt, axis=2)
# /home/liyuan3970/anaconda3/lib/python3.7/site-packages/numpy/ma/extras.py:605: RuntimeWarning: invalid value encountered in multiply
#   wgt = wgt*(~a.mask)
# <class 'cinrad.datastruct.Grid'>
