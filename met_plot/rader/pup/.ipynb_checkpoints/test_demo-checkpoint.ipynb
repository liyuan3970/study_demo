# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as mp
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
r = f.get_data(tilt_number, data_radius, data_dtype)

data = r.data
print(data.shape)
x1=[i for i in range(230)]
y1=[i for i in range(366)]
x,y=np.meshgrid(x1,y1)

z=data

# 绘制图形
mp.figure('Contour', facecolor='lightgray')
mp.title('Contour', fontsize=14)
mp.xlabel('x', fontsize=12)
mp.ylabel('y', fontsize=12)
mp.tick_params(labelsize=10)
mp.grid(linestyle=':')
# 绘制等高线图
cntr = mp.contour(x, y, z, 8, colors='black',
                  linewidths=0.5)
mp.contourf(x, y, z, 8, cmap='jet')
mp.show()
# Out:
# (366, 230)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as mp
from cinrad.visualize import PPI
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
r = f.get_data(tilt_number, data_radius, data_dtype)
v = []
v.append(r)
f =cinrad.easycalc.GridMapper(v)
grid = f(0.01)
print(grid.data)
print(type(f))
PPI(grid)
# data = r.data
# print(data.shape)
# x1=[i for i in range(230)]
# y1=[i for i in range(366)]
# x,y=np.meshgrid(x1,y1)

# z=data

# # 绘制图形
# mp.figure('Contour', facecolor='lightgray')
# mp.title('Contour', fontsize=14)
# mp.xlabel('x', fontsize=12)
# mp.ylabel('y', fontsize=12)
# mp.tick_params(labelsize=10)
# mp.grid(linestyle=':')
# # 绘制等高线图
# cntr = mp.contour(x, y, z, 8, colors='black',
#                   linewidths=0.5)

# mp.contourf(x, y, z, 8, cmap='jet')

# mp.show()
# Out:
# /home/lliyuan3970/anaconda3/lib/python3.7/site-packages/cinrad-1.5-py3.7-linux-x86_64.egg/cinrad/easycalc.py:407: RuntimeWarning: divide by zero encountered in true_divide
#   return np.ma.average(inp, weights=1 / wgt, axis=2)
# /home/lliyuan3970/anaconda3/lib/python3.7/site-packages/numpy/ma/extras.py:625: RuntimeWarning: invalid value encountered in multiply
#   wgt = wgt*(~a.mask)
# [[-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]
# <class 'cinrad.easycalc.GridMapper'>
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as mp
from cinrad.visualize import PPI
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
r = f.get_data(tilt_number, data_radius, data_dtype)
v = []
v.append(r)
f =cinrad.easycalc.GridMapper(v)
grid = f(0.01)
print(grid.data)
print(type(f))
# PPI(grid)
data = grid.data
x1=[i for i in range(474)]
y1=[i for i in range(416)]
x,y=np.meshgrid(x1,y1)

z=data
print('zshape',z.shape)
print(grid.drange)
print('lon',grid.lon)
print(grid.lat)
print(grid.scan_info)
print(grid.stp)
print(grid.scantime)
print(grid.dtype)


#绘制图形
mp.figure('Contour', facecolor='lightgray')
mp.title('Contour', fontsize=14)
mp.xlabel('x', fontsize=12)
mp.ylabel('y', fontsize=12)
mp.tick_params(labelsize=10)
mp.grid(linestyle=':')
# 绘制等高线图
cntr = mp.contour(x, y, z, 8, colors='black',
                  linewidths=0.5)

mp.contourf(x, y, z, 8, cmap='jet')

mp.show()
# Out:
# [[-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]
# <class 'cinrad.easycalc.GridMapper'>
# zshape (416, 474)
# nan
# lon [[119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  ...
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]]
# [[26.55 26.55 26.55 ... 26.55 26.55 26.55]
#  [26.56 26.56 26.56 ... 26.56 26.56 26.56]
#  [26.57 26.57 26.57 ... 26.57 26.57 26.57]
#  ...
#  [30.68 30.68 30.68 ... 30.68 30.68 30.68]
#  [30.69 30.69 30.69 ... 30.69 30.69 30.69]
#  [30.7  30.7  30.7  ... 30.7  30.7  30.7 ]]
# {}
# {'lon': 0, 'lat': 0}
# 2019-08-10 00:10:47
# REF

# %% [markdown]
# ## 读取雷达的高度数据，并网格化

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as mp
from cinrad.visualize import PPI
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
r = f.get_data(tilt_number, data_radius, data_dtype)
height = r.height
r.data = height
v = []
v.append(r)
f =cinrad.easycalc.GridMapper(v)
grid = f(0.01)
print(grid.data)
print(type(f))
# PPI(grid)
data = grid.data
x1=[i for i in range(474)]
y1=[i for i in range(416)]
x,y=np.meshgrid(x1,y1)
z=data
print('zshape',z.shape)
print(grid.drange)
print(grid.lon)
print(grid.lat)
print(grid.scan_info)
print(grid.stp)
print(grid.scantime)
print(grid.dtype)


#绘制图形
mp.figure('Contour', facecolor='lightgray')
mp.title('Contour', fontsize=14)
mp.xlabel('x', fontsize=12)
mp.ylabel('y', fontsize=12)
mp.tick_params(labelsize=10)
mp.grid(linestyle=':')
# 绘制等高线图
cntr = mp.contour(x, y, z, 8, colors='black',
                  linewidths=0.5)

mp.contourf(x, y, z, 8, cmap='jet')

mp.show()
# Out:
# [[-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]
# <class 'cinrad.easycalc.GridMapper'>
# zshape (416, 474)
# nan
# [[119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  ...
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]
#  [119.16 119.17 119.18 ... 123.87 123.88 123.89]]
# [[26.55 26.55 26.55 ... 26.55 26.55 26.55]
#  [26.56 26.56 26.56 ... 26.56 26.56 26.56]
#  [26.57 26.57 26.57 ... 26.57 26.57 26.57]
#  ...
#  [30.68 30.68 30.68 ... 30.68 30.68 30.68]
#  [30.69 30.69 30.69 ... 30.69 30.69 30.69]
#  [30.7  30.7  30.7  ... 30.7  30.7  30.7 ]]
# {}
# {'lon': 0, 'lat': 0}
# 2019-08-10 00:10:47
# REF

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)
print('height',ra.height.shape)
data = ra.data
values = data
print(values.shape)
azimuths = np.radians(np.linspace(0, 360, 366))
zeniths = np.arange(0, 230, 1)
print(azimuths.shape)
print(zeniths.shape)
r, theta = np.meshgrid(zeniths, azimuths)
print(r.shape)
print(theta.shape)
fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
ax.contourf(theta, r, values)

plt.show()
# Out:
# height (366, 230)
# (366, 230)
# (366,)
# (230,)
# (366, 230)
# (366, 230)

# %%
import numpy as np
import matplotlib.pyplot as plt

#-- Generate Data -----------------------------------------
# Using linspace so that the endpoint of 360 is included...
azimuths = np.radians(np.linspace(0, 360, 20))
zeniths = np.arange(0, 70, 10)
print(azimuths.shape)
print(zeniths.shape)
r, theta = np.meshgrid(zeniths, azimuths)
values = np.random.random((azimuths.size, zeniths.size))
print(values.shape)

#-- Plot... ------------------------------------------------
fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
print(r.shape)
print(theta.shape)
ax.contourf(theta, r, values)

plt.show()
# Out:
# (20,)
# (7,)
# (20, 7)
# (20, 7)
# (20, 7)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)
print('height',ra.height.shape)
height = ra.height
print(height.shape)
data = ra.data
values = data
print(values.shape)
azimuths = np.radians(np.linspace(0, 360, 366))
zeniths = np.arange(0, 230, 1)
print(azimuths.shape)
print(zeniths.shape)
r, theta = np.meshgrid(zeniths, azimuths)
print(r.shape)
print(theta.shape)
#fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(r, theta, height, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))
# zdir : 'z' | 'x' | 'y' 表示把等高线图投射到哪个面
# offset : 表示等高线图投射到指定页面的某个刻度
# ax.contourf(r, theta, height,zdir='z',offset=-2)
# 设置图像z轴的显示范围，x、y轴设置方式相同
# ax.set_zlim(-2,2)
plt.show()
# Out:
# height (366, 230)
# (366, 230)
# (366, 230)
# (366,)
# (230,)
# (366, 230)
# (366, 230)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)
print('height',ra.height.shape)
height = ra.height
print(height.shape)
data = ra.data
values = data
print(values.shape)
azimuths = np.radians(np.linspace(0, 360, 366))
zeniths = np.arange(0, 230, 1)
print(azimuths.shape)
print(zeniths.shape)
r, theta = np.meshgrid(zeniths, azimuths)
print(r.shape)
print(theta.shape)
#fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
# ax.scatter(r, theta,data,d=c,cmap='jet', s=40,
#              label='Points')
ax.contourf(r, theta,data,zdir='z',offset=-2)
# plt.xlim((-10, 10))
# plt.ylim((-10, 10))
plt.show()
# Out:
# height (366, 230)
# (366, 230)
# (366, 230)
# (366,)
# (230,)
# (366, 230)
# (366, 230)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
r = f.get_data(tilt_number, data_radius, data_dtype)
v = []
v.append(r)
f =cinrad.easycalc.GridMapper(v)
grid = f(0.1)

lon = grid.lon
print(lon.shape)
lat = grid.lat
# x,y=np.meshgrid(lon, lat)
data = grid.data
print(data.shape)
ra = r
ra.data = r.height
a = []
a.append(ra)
fa =cinrad.easycalc.GridMapper(a)
height = fa(0.1)
print(lon.shape)
# print(height.data.shape)
# print(height.lon.shape)

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
h = height.data
print(h.shape)
print(h)
ax.scatter(lon, lat,h,cmap='jet', s=40,
             label='Points')
#ax.plot_surface(lon, lat,h, rstride=1, cstride=1, cmap=plt.get_cmap('rainbow'))
ax = fig.add_subplot(111, projection='3d')
ax.contourf(lon,lat,data,zdir='z',offset=-2)
# Out:
# (43, 49)
# (43, 49)
# (43, 49)
# (43, 49)
# [[-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from cinrad.visualize import PPI
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
r = f.get_data(tilt_number, data_radius, data_dtype)
height = r.height
r.data = height
v = []
v.append(r)
f =cinrad.easycalc.GridMapper(v)
grid = f(0.1)
lon = grid.lon
print(lon.shape)
lat = grid.lat
print(grid.data)
print(type(f))
# PPI(grid)
data = grid.data

f1 = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
r1 = f1.get_data(tilt_number, data_radius, data_dtype)
v1 = []
v1.append(r)
f2 =cinrad.easycalc.GridMapper(v1)
grid1 = f2(0.1)
data1 = grid1.data

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
ax = Axes3D(fig)
ax.scatter(lon, lat,data,cmap='jet', s=40,
             label='Points')
ax.contourf(lon,lat,data1,zdir='z',offset=-2)
# Out:
# (43, 49)
# [[-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  ...
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]
#  [-- -- -- ... -- -- --]]
# <class 'cinrad.easycalc.GridMapper'>

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.use('TkAgg')
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)

v = []
v.append(ra)
gmap =cinrad.easycalc.GridMapper(v)
grid = gmap(0.1)
lon = grid.lon
lat = grid.lat
data = grid.data

h = []
height = ra.height
rb = ra
rb.data = height
h.append(rb)
gcma = cinrad.easycalc.GridMapper(h)
gcmd = gcma(0.1)
lon2 = gcmd.lon
lat2 = gcmd.lat
hig = gcmd.data
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(lon2, lat2,hig,cmap='jet', s=40,
             label='Points')
ax.contourf(lon,lat,data,zdir='z',offset=-2)



plt.show()

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm, colors
# ncl调色板的配置
fid = open('radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
cmaps= colors.ListedColormap(rgb)



#matplotlib.use('TkAgg')
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)

v = []
v.append(ra)
gmap =cinrad.easycalc.GridMapper(v)
grid = gmap(0.1)
lon = grid.lon
lat = grid.lat
data = grid.data

h = []
height = ra.height
rb = ra
rb.data = height
h.append(rb)
gcma = cinrad.easycalc.GridMapper(h)
gcmd = gcma(0.1)
lon2 = gcmd.lon
lat2 = gcmd.lat
hig = gcmd.data
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
color_map =data.reshape(43*49)
print(color_map.shape)
ax.scatter(lon2, lat2,hig,c=color_map,cmap=cmaps, s=5)

#ax.plot_surface(lon2, lat2,hig, c=color_map,rstride=1, cstride=1, cmap=cmaps)
print(lon2.shape)
print(lat2.shape)
print(hig.shape)
print(data.shape)
# ax.scatter(lon2, lat2,hig,cmap='jet', s=40,
#              label='Points')
# ax.contourf(lon,lat,data,zdir='z',offset=-2)
ax.contourf(lon,lat,data,cmap=cmaps,zdir='z',offset=-20)


plt.show()
# Out:
# (15, 3)
# (2107,)
# (43, 49)
# (43, 49)
# (43, 49)
# (43, 49)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
import matplotlib.colors as mcolors


# 画出显著变化和不显著变化趋势的站点，同时标注显著变化者senslope的大小
def plot_scatter():
	fig = plt.figure(figsize=(6,4))

	# customized colormap
	colors = ['lightskyblue', 'deepskyblue', 'dodgerblue', 'royalblue', 'mediumblue', 'navy']
	cmap = mpl.colors.ListedColormap(colors[::-1]) # 让颜色倒过来，原来的

	# even bounds gives a contour-like effect
	bounds = [ round(elem, 3) for elem in np.linspace(-0.15, -0.05, 5)] # 
	# get one more color than bounds from colormap 在bounds之外再多一个颜色
	colors = plt.get_cmap(cmap)(np.linspace(0,1,len(bounds)+1))
	# create colormap without the outmost colors 不用最外面的颜色来创造colormap
	cmap = mpl.colors.ListedColormap(colors[1:-1]) # 1:-1是从第二个到倒数第二个，左闭右开
	# set upper/lower color 
	cmap.set_over(colors[-1])
	cmap.set_under(colors[0])

	m = Basemap(llcrnrlon=113.7, llcrnrlat=22.35, urcrnrlon=114.7, urcrnrlat=22.9,\
			rsphere=(6378137.00,6356752.3142),\
			resolution='l', area_thresh=1000., projection='lcc', lat_1=22.5, lat_0=22.5, lon_0=114) #- shape文件，画出区域轮廓

	lons = [114.1267222, 114.111825, 114.04908059999998, 113.8175, 114.47, 114.1122222, 114.1658333, 114.0036111, 113.8936271, 113.8855675, 114.104705, 114.1508333, 114.5002778, 113.7672222, 114.1011111, 113.9536389, 113.8911111, 113.8979694, 114.5340278, 114.1436111, 114.2238889, 114.3366799, 114.3044444, 113.9308333, 114.3922222, 113.9147222, 113.8361111, 114.02916670000002, 114.2236111, 113.8686111, 114.1488889, 114.1230556, 114.1933333, 114.02916670000002, 113.9727778, 114.48444440000002, 114.2752778, 114.2422222, 114.01416670000002, 113.9288889, 114.5264328, 113.94485559999998, 114.19001670000002, 114.4861111, 114.1794444, 114.2430556, 114.1508333, 114.09555559999998, 114.2622222, 114.0163889, 114.3002778, 114.3552778, 113.8602778, 113.8797222, 114.2338889, 114.0708333, 114.43194440000002, 113.89305559999998]
	lats = [22.55097222, 22.55905833, 22.52501111, 22.67416667, 22.60055556, 22.60555556, 22.56472222, 22.54166667, 22.65377067, 22.47006253, 22.54966819, 22.55166667, 22.56944444, 22.72333333, 22.57194444, 22.76244444, 22.78166667, 22.70483, 22.59697222, 22.57166667, 22.555, 22.59546331, 22.7775, 22.48861111, 22.615, 22.5475, 22.77916667, 22.62305556, 22.64638889, 22.495, 22.61638889, 22.69611111, 22.64638889, 22.5725, 22.59638889, 22.53444444, 22.56666667, 22.72416667, 22.54888889, 22.67888889, 22.48137411, 22.50378611, 22.57101111, 22.48277778, 22.66222222, 22.58388889, 22.65611111, 22.5375, 22.76694444, 22.53027778, 22.67888889, 22.7125, 22.80166667, 22.55277778, 22.68527778, 22.56861111, 22.61888889, 22.58861111]
	values = [-0.03101638020010544, -0.059602408594572324, -0.08074725429957398, -0.052523178817571285, -0.06097954730989012, -0.048576189387818935, -0.05321303447484441, -0.08990485880945824, -0.07035292627778422, -0.08904485101486563, -0.050582862579880206, -0.08667040863306046, -0.2381958334486063, -0.09043589588854052, -0.015791558268944444, -0.04750735872842685, -0.0827816789190754, -0.0495746307369816, -0.09748174185420576, -0.05328468550193526, -0.0385492789056475, -0.12603457458801204, -0.03785426812465535, -0.10934222695289253, -0.06257603144203898, -0.05322345906174508, -0.0437720889282609, -0.029440526555296737, -0.0446847919726688, -0.05879880517527025, -0.042610207214769935, -0.07981280621664595, -0.056233334347744406, -0.07486982006522186, -0.064798640683293, -0.060273137801299975, -0.08829009917157292, -0.02696058143578384, -0.047529515842470234, -0.051839812353009496, -0.05970518244018841, -0.08892429975993077, -0.2594588992844997, -0.0853022809983619, -0.11143855759589913, -0.05064439000559071, -0.02366547879452241, -0.1743014882414493, -0.05539755391763087, -0.04722722346208863, -0.04903534243112728, -0.0613871242134162, -0.05259194456906426, -0.0933057542530412, -0.05063961430132472, -0.05351251987776765, -0.03849744311833736, -0.04819026109972248]

	sgt_scatter = m.scatter(lons, lats, s=60, c=values, marker="o", vmin=-0.15, vmax=-0.05, latlon=True, cmap=cmap)

	m.colorbar(extend='both', ticks=bounds)

	m.drawmeridians(np.arange(10, 125, 0.5), labels=[1,0,0,1])
	m.drawparallels(np.arange(15, 30, 0.3),labels=[1,0,0,0])
	plt.show()

if __name__ == '__main__':
	plot_scatter()

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm, colors
from matplotlib import cm
# ncl调色板的配置
fid = open('radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
cmaps= colors.ListedColormap(rgb)



#matplotlib.use('TkAgg')
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)

v = []
v.append(ra)
gmap =cinrad.easycalc.GridMapper(v)
grid = gmap(0.1)
lon = grid.lon
lat = grid.lat
data = grid.data

h = []
height = ra.height
rb = ra
rb.data = height
h.append(rb)
gcma = cinrad.easycalc.GridMapper(h)
gcmd = gcma(0.1)
lon2 = gcmd.lon
lat2 = gcmd.lat
hig = gcmd.data
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
color_map =data.reshape(43*49)
print(color_map.shape)
# ax.scatter(lon2, lat2,hig,c=color_map,cmap=cmaps, s=5)

#ax.plot_surface(lon2, lat2,hig,facecolors=data,rstride=1, cstride=1, cmap=cmaps,shade=True)
ax.plot_surface(lon2, lat2,hig,facecolors=cm.jet(data),rstride=1, cstride=1)
print(lon2.shape)
print(lat2.shape)
print(hig.shape)
print(data.shape)
# ax.scatter(lon2, lat2,hig,cmap='jet', s=40,
#              label='Points')
# ax.contourf(lon,lat,data,zdir='z',offset=-2)
ax.contourf(lon,lat,data,cmap=cmaps,zdir='z',offset=-20)


plt.show()
# Out:
# (15, 3)
# (2107,)
# (43, 49)
# (43, 49)
# (43, 49)
# (43, 49)

# %%
# Python-matplotlib Commands
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=np.gradient(Z), linewidth=0, antialiased=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-988d436b4f0a> in <module>
#      12 R = np.sqrt(X**2 + Y**2)
#      13 Z = np.sin(R)
# ---> 14 surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=np.gradient(Z), linewidth=0, antialiased=False)
#      15 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1691         # note that the striding causes some polygons to have more coordinates
#    1692         # than others
# -> 1693         polyc = art3d.Poly3DCollection(polys, *args, **kwargs)
#    1694
#    1695         if fcolors is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py in __init__(self, verts, zsort, *args, **kwargs)
#     524         and _edgecolors properties.
#     525         """
# --> 526         super().__init__(verts, *args, **kwargs)
#     527         self.set_zsort(zsort)
#     528         self._codes3d = None
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, verts, sizes, closed, **kwargs)
#     931         %(Collection)s
#     932         """
# --> 933         Collection.__init__(self, **kwargs)
#     934         self.set_sizes(sizes)
#     935         self.set_verts(verts, closed)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     117         """
#     118         artist.Artist.__init__(self)
# --> 119         cm.ScalarMappable.__init__(self, norm, cmap)
#     120         # list of un-scaled dash patterns
#     121         # this is needed scaling the dash pattern by linewidth
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py in __init__(self, norm, cmap)
#     215         self.norm = norm
#     216         #: The Colormap instance of this ScalarMappable.
# --> 217         self.cmap = get_cmap(cmap)
#     218         #: The last colorbar associated with this ScalarMappable. May be None.
#     219         self.colorbar = None
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py in get_cmap(name, lut)
#     172         return name
#     173
# --> 174     if name in cmap_d:
#     175         if lut is None:
#     176             return cmap_d[name]
#
# TypeError: unhashable type: 'list'

# %%
# Python-matplotlib Commands
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, .25)
Y = np.arange(-5, 5, .25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
Gx, Gy = np.gradient(Z) # gradients with respect to x and y
G = (Gx**2+Gy**2)**.5  # gradient magnitude
N = G/G.max()  # normalize 0..1
surf = ax.plot_surface(
    X, Y, Z, rstride=1, cstride=1,
    facecolors=cm.jet(N),
    linewidth=0, antialiased=False, shade=False)
plt.show()

# %%
# Python-matplotlib Commands
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, .25)
Y = np.arange(-5, 5, .25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
Gx, Gy = np.gradient(Z) # gradients with respect to x and y
G = (Gx**2+Gy**2)**.5  # gradient magnitude
N = G/G.max()  # normalize 0..1
surf = ax.plot_surface(
    X, Y, Z, rstride=1, cstride=1,
    cmap='jet',
    linewidth=0, antialiased=False, shade=False)
plt.show()

# %%
# Python-matplotlib Commands
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, .25)
Y = np.arange(-5, 5, .25)
X, Y = np.meshgrid(X, Y)
print(X.shape)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
Gx, Gy = np.gradient(Z) # gradients with respect to x and y
G = (Gx**2+Gy**2)**.5  # gradient magnitude
N = G/G.max()  # normalize 0..1

print(N.shape)
surf = ax.plot_surface(
    X, Y, Z, rstride=1, cstride=1,
    facecolors=cm.jet(N),
    linewidth=0, antialiased=False, shade=False)
plt.show()
# Out:
# (40, 40)
# (40, 40)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm, colors
from matplotlib import cm
# ncl调色板的配置
fid = open('radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
cmaps= colors.ListedColormap(rgb)



#matplotlib.use('TkAgg')
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)

v = []
v.append(ra)
gmap =cinrad.easycalc.GridMapper(v)
grid = gmap(0.1)
lon = grid.lon
lat = grid.lat
data = grid.data

h = []
height = ra.height
rb = ra
rb.data = height
h.append(rb)
gcma = cinrad.easycalc.GridMapper(h)
gcmd = gcma(0.1)
lon2 = gcmd.lon
lat2 = gcmd.lat
hig = gcmd.data
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
color_map =data.reshape(43*49)
print(color_map.shape)
# ax.scatter(lon2, lat2,hig,c=color_map,cmap=cmaps, s=5)

#ax.plot_surface(lon2, lat2,hig,facecolors=data,rstride=1, cstride=1, cmap=cmaps,shade=True)
ax.plot_surface(lon2, lat2,hig,facecolors=cmaps(data/100),rstride=1, cstride=1)
print(lon2.shape)
print(lat2.shape)
print(hig.shape)
print(data.shape)
# ax.scatter(lon2, lat2,hig,cmap='jet', s=40,
#              label='Points')
# ax.contourf(lon,lat,data,zdir='z',offset=-2)
ax.contourf(lon,lat,data,cmap=cmaps,zdir='z',offset=-20)


plt.show()
# Out:
# (15, 3)
# (2107,)
# (43, 49)
# (43, 49)
# (43, 49)
# (43, 49)

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
 
fig = plt.figure()
ax = fig.gca(projection='3d')
 
# Make the grid
x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))
 
# Make the direction data for the arrows
u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))
 
ax.quiver(x, y, z, u, v, w, length=0.1, normalize=True)
 
plt.show()

# %% [markdown]
# # 颜色标准化

# %%
import matplotlib.cm as cm

print(cm.hot(0.3))
# Out:
# (0.8240081481370484, 0.0, 0.0, 1.0)

# %%
import matplotlib as mpl
import matplotlib.cm as cm

norm = mpl.colors.Normalize(vmin=-20, vmax=10)
cmap = cm.hot
x = 0.3

m = cm.ScalarMappable(norm=norm, cmap=cmap)
print(m.to_rgba(x))
# Out:
# (1.0, 0.8225486412996345, 0.0, 1.0)

# %%
import matplotlib as mpl
import matplotlib.cm as cm

norm = mpl.colors.Normalize(vmin=-10, vmax=10)
cmap = cm.hot
x = 0.3
a=cmap(0.3)
print('a',a)
m = cm.ScalarMappable(norm=norm, cmap=cmap)
print(m)
print(m.to_rgba(x))
# Out:
# a (0.8240081481370484, 0.0, 0.0, 1.0)
# <matplotlib.cm.ScalarMappable object at 0x7ff694948e80>
# (1.0, 0.3901964026955515, 0.0, 1.0)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm, colors
from matplotlib import cm
# ncl调色板的配置
fid = open('radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
cmaps= colors.ListedColormap(rgb)



#matplotlib.use('TkAgg')
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)

v = []
v.append(ra)
gmap =cinrad.easycalc.GridMapper(v)
grid = gmap(0.1)
lon = grid.lon
lat = grid.lat
data = grid.data

h = []
height = ra.height
rb = ra
rb.data = height
h.append(rb)
gcma = cinrad.easycalc.GridMapper(h)
gcmd = gcma(0.1)
lon2 = gcmd.lon
lat2 = gcmd.lat
hig = gcmd.data
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
# 创建3d图形的两种方式
# ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
color_map =data.reshape(43*49)
print(color_map.shape)
# ax.scatter(lon2, lat2,hig,c=color_map,cmap=cmaps, s=5)
import matplotlib as mpl
import matplotlib.cm as cm
norm = mpl.colors.Normalize(vmin=0, vmax=70)
m = cm.ScalarMappable(norm=norm, cmap=cmaps)
#ax.plot_surface(lon2, lat2,hig,facecolors=data,rstride=1, cstride=1, cmap=cmaps,shade=True)
ax.plot_surface(lon2, lat2,hig,facecolors=m.to_rgba(data),rstride=1, cstride=1)
#ax.plot_surface(lon2, lat2,hig,facecolors=cmaps(data/40),rstride=1, cstride=1)
# print('max',max(data))
# print('min',min(data))
print(lon2.shape)
print(lat2.shape)
print(hig.shape)
print(data.shape)
# ax.scatter(lon2, lat2,hig,cmap='jet', s=40,
#              label='Points')
# ax.contourf(lon,lat,data,zdir='z',offset=-2)
ax.contourf(lon,lat,data,cmap=cmaps,zdir='z',offset=-20)


plt.show()
# Out:
# (15, 3)
# (2107,)
# (43, 49)
# (43, 49)
# (43, 49)
# (43, 49)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm, colors
from matplotlib import cm
from mpl_toolkits.basemap import Basemap
# ncl调色板的配置
fid = open('radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
cmaps= colors.ListedColormap(rgb)



#matplotlib.use('TkAgg')
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)

v = []
v.append(ra)
gmap =cinrad.easycalc.GridMapper(v)
grid = gmap(0.1)
lon = grid.lon
lat = grid.lat
data = grid.data

h = []
height = ra.height
rb = ra
rb.data = height
h.append(rb)
gcma = cinrad.easycalc.GridMapper(h)
gcmd = gcma(0.1)
lon2 = gcmd.lon
lat2 = gcmd.lat
hig = gcmd.data
#map = Basemap(llcrnrlon=120.2,llcrnrlat=27.6,urcrnrlon=122.5,urcrnrlat=29.5)
map = Basemap(llcrnrlon=119,llcrnrlat=25,urcrnrlon=125,urcrnrlat=32)
#map.drawcoastlines()
map.drawcountries()
map.readshapefile('taizhou', 'taizhou',linewidth=0.75)

map.contourf(lon,lat,data,cmap=cmaps)
# Out:
# (15, 3)

# %%
import cinrad
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm, colors
from matplotlib import cm
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d import Axes3D
# ncl调色板的配置
fid = open('radar.rgb')
data=fid.readlines()
n=len(data);
#print(n)
rgb=np.zeros((n,3))
for i in np.arange(n):
    #print(data[0].split(' '))
    rgb[i][0]=float(data[i].split(' ')[0])
    rgb[i][1]=data[i].split(' ')[1]
    rgb[i][2]=data[i].split(' ')[2]
print((rgb.shape))
#print(rgb[253])
cmaps= colors.ListedColormap(rgb)



#matplotlib.use('TkAgg')
f = cinrad.io.CinradReader('Z_RADR_I_Z9576_20190810000600_O_DOR_SA_CAP.bin.bz2')
tilt_number = 0
data_radius = 230
data_dtype = 'REF' # stands for reflectivity
ra = f.get_data(tilt_number, data_radius, data_dtype)

v = []
v.append(ra)
gmap =cinrad.easycalc.GridMapper(v)
grid = gmap(0.1)
lon = grid.lon
lat = grid.lat
data = grid.data

h = []
height = ra.height
rb = ra
rb.data = height
h.append(rb)
gcma = cinrad.easycalc.GridMapper(h)
gcmd = gcma(0.1)
lon2 = gcmd.lon
lat2 = gcmd.lat
hig = gcmd.data
map = Basemap(llcrnrlon=119,llcrnrlat=25,urcrnrlon=125,urcrnrlat=32)
fig = plt.figure()
ax = Axes3D(fig)
#ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
ax.add_collection3d(map.drawcountries(linewidth=0.35))
#map.contourf(lon,lat,data,cmap=cmaps)
ax.contourf(lon,lat,data,cmap=cmaps)

#map.contourf(lon,lat,data)
#ax.add_collection3d(map.contourf(lon,lat,data,cmap=cmaps))
#ax.add_collection3d(map.readshapefile('taizhou', 'taizhou',linewidth=0.75))
plt.show()
# Out:
# (15, 3)
