# %% [markdown]
# # 直角坐标系
# ## Bar

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
bar=Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="021cb6f86bfd4cd38709990b54dfef9b" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_021cb6f86bfd4cd38709990b54dfef9b = echarts.init(
#             document.getElementById('021cb6f86bfd4cd38709990b54dfef9b'), 'white', {renderer: 'canvas'});
#         var option_021cb6f86bfd4cd38709990b54dfef9b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar= Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values(), category_gap="60%")
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})
bar.set_global_opts(title_opts=opts.TitleOpts(title="Bar-渐变圆柱"))
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="8544619a1c3a438190ba8aa9c1d980e9" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_8544619a1c3a438190ba8aa9c1d980e9 = echarts.init(
#             document.getElementById('8544619a1c3a438190ba8aa9c1d980e9'), 'white', {renderer: 'canvas'});
#         var option_8544619a1c3a438190ba8aa9c1d980e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar=Bar(
            init_opts=opts.InitOpts(
                animation_opts=opts.AnimationOpts(
                    animation_delay=1000, animation_easing="elasticOut"
                )
            )
        )
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-动画配置基本示例", subtitle="我是副标题")
        )
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="c1f83ac6d1b94c5bba54eba959a1c77d" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_c1f83ac6d1b94c5bba54eba959a1c77d = echarts.init(
#             document.getElementById('c1f83ac6d1b94c5bba54eba959a1c77d'), 'white', {renderer: 'canvas'});
#         var option_c1f83ac6d1b94c5bba54eba959a1c77d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "elasticOut",
#     "animationDelay": 1000,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar=Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(
            title_opts={"text": "Bar-通过 dict 进行配置", "subtext": "我也是通过 dict 进行配置的"}
        )
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="cb9ae31df7f14b218c8f3ddeca5393bc" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_cb9ae31df7f14b218c8f3ddeca5393bc = echarts.init(
#             document.getElementById('cb9ae31df7f14b218c8f3ddeca5393bc'), 'white', {renderer: 'canvas'});
#         var option_cb9ae31df7f14b218c8f3ddeca5393bc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar=Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-显示 ToolBox"),
            toolbox_opts=opts.ToolboxOpts(),
            legend_opts=opts.LegendOpts(is_show=False)
        )
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="57b9c23f8a38473a8996fb5eec7bd932" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_57b9c23f8a38473a8996fb5eec7bd932 = echarts.init(
#             document.getElementById('57b9c23f8a38473a8996fb5eec7bd932'), 'white', {renderer: 'canvas'});
#         var option_57b9c23f8a38473a8996fb5eec7bd932 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar=Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values(), category_gap="80%")
bar.set_global_opts(title_opts=opts.TitleOpts(title="Bar-单系列柱间距离"))
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="4c129fa781a54164a72ab87a5e5fc3d0" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_4c129fa781a54164a72ab87a5e5fc3d0 = echarts.init(
#             document.getElementById('4c129fa781a54164a72ab87a5e5fc3d0'), 'white', {renderer: 'canvas'});
#         var option_4c129fa781a54164a72ab87a5e5fc3d0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar=Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values(), gap="0%")
bar.add_yaxis("商家B", Faker.values(), gap="0%")
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-不同系列柱间距离"),
        )
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="0cfdd10afa394149a50df32161855990" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_0cfdd10afa394149a50df32161855990 = echarts.init(
#             document.getElementById('0cfdd10afa394149a50df32161855990'), 'white', {renderer: 'canvas'});
#         var option_0cfdd10afa394149a50df32161855990 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar=Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-Y 轴 formatter"),
            yaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter="{value} /月")
            ),
        )
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="6267cda918864da7bbb7d5bff5e59824" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_6267cda918864da7bbb7d5bff5e59824 = echarts.init(
#             document.getElementById('6267cda918864da7bbb7d5bff5e59824'), 'white', {renderer: 'canvas'});
#         var option_6267cda918864da7bbb7d5bff5e59824 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
bar=Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-XY 轴名称"),
            yaxis_opts=opts.AxisOpts(name="我是 Y 轴"),
            xaxis_opts=opts.AxisOpts(name="我是 X 轴"),
        )
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="ab12a37155cc436bb675f48acaf3d48e" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_ab12a37155cc436bb675f48acaf3d48e = echarts.init(
#             document.getElementById('ab12a37155cc436bb675f48acaf3d48e'), 'white', {renderer: 'canvas'});
#         var option_ab12a37155cc436bb675f48acaf3d48e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
# ...

# %%
def bar_reversal_axis() -> Bar:
    c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="right"))
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-翻转 XY 轴"))
        .load_javascript()
    )
    return c

# %%
bar=bar_reversal_axis()

# %%
bar.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-fc8263bd7096> in <module>
# ----> 1 bar.render_notebook()
#
# AttributeError: 'Javascript' object has no attribute 'render_notebook'
