# %% [markdown]
# # 日历图

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar


begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [[str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)] for i in range((end - begin).days + 1) ]

calendar = Calendar()

calendar.add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
calendar.set_global_opts(
    title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
    visualmap_opts=opts.VisualMapOpts(
    max_=20000,
    min_=500,
    orient="horizontal",
    is_piecewise=True,
    pos_top="230px",
    pos_left="100px",), )
calendar.load_javascript()

# %%
calendar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1cd774633a854b8ebd242c384e495141" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1cd774633a854b8ebd242c384e495141 = echarts.init(
#             document.getElementById('1cd774633a854b8ebd242c384e495141'), 'white', {renderer: 'canvas'});
#         var option_1cd774633a854b8ebd242c384e495141 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2017-01-01",
#                     13066
#                 ],
#                 [
#                     "2017-01-02",
#                     12041
#                 ],
#                 [
#                     "2017-01-03",
#                     23530
#                 ],
#                 [
#                     "2017-01-04",
#                     14859
#                 ],
#                 [
#                     "2017-01-05",
#                     21070
#                 ],
#                 [
#                     "2017-01-06",
#                     21006
#                 ],
#                 [
#                     "2017-01-07",
#                     3622
#                 ],
#                 [
#                     "2017-01-08",
#                     14594
#                 ],
#                 [
#                     "2017-01-09",
#                     1307
#                 ],
#                 [
#                     "2017-01-10",
#                     17608
#                 ],
#                 [
#                     "2017-01-11",
#                     13917
#                 ],
#                 [
#                     "2017-01-12",
#                     21701
#                 ],
#                 [
#                     "2017-01-13",
#                     8894
#                 ],
#                 [
#                     "2017-01-14",
#                     19110
#                 ],
#                 [
#                     "2017-01-15",
#                     15676
#                 ],
#                 [
#                     "2017-01-16",
#                     22106
#                 ],
#                 [
#                     "2017-01-17",
#                     6264
#                 ],
#                 [
#                     "2017-01-18",
#                     10853
#                 ],
#                 [
#                     "2017-01-19",
#                     3925
#                 ],
#                 [
#                     "2017-01-20",
#                     15351
#                 ],
#                 [
#                     "2017-01-21",
#                     20767
#                 ],
#                 [
#                     "2017-01-22",
#                     10738
#                 ],
#                 [
#                     "2017-01-23",
#                     14117
#                 ],
#                 [
#                     "2017-01-24",
#                     20977
#                 ],
#                 [
#                     "2017-01-25",
#                     21641
#                 ],
#                 [
#                     "2017-01-26",
#                     12760
#                 ],
#                 [
#                     "2017-01-27",
#                     11459
#                 ],
#                 [
#                     "2017-01-28",
#                     24696
#                 ],
#                 [
#                     "2017-01-29",
#                     17893
#                 ],
#                 [
#                     "2017-01-30",
#                     3596
#                 ],
#                 [
#                     "2017-01-31",
#                     19138
#                 ],
#                 [
#                     "2017-02-01",
#                     13497
#                 ],
#                 [
#                     "2017-02-02",
#                     8061
#                 ],
#                 [
#                     "2017-02-03",
#                     7393
#                 ],
#                 [
#                     "2017-02-04",
#                     2310
#                 ],
#                 [
#                     "2017-02-05",
#                     8983
#                 ],
#                 [
#                     "2017-02-06",
#                     23098
#                 ],
#                 [
#                     "2017-02-07",
#                     3438
#                 ],
#                 [
#                     "2017-02-08",
#                     13164
#                 ],
#                 [
#                     "2017-02-09",
#                     24048
#                 ],
#                 [
#                     "2017-02-10",
#                     6666
#                 ],
#                 [
#                     "2017-02-11",
#                     1142
#                 ],
#                 [
#                     "2017-02-12",
#                     5240
#                 ],
#                 [
#                     "2017-02-13",
#                     21455
#                 ],
#                 [
#                     "2017-02-14",
#                     22779
#                 ],
#                 [
#                     "2017-02-15",
#                     23605
#                 ],
#                 [
#                     "2017-02-16",
#                     14340
#                 ],
#                 [
#                     "2017-02-17",
#                     5543
#                 ],
#                 [
#                     "2017-02-18",
#                     6326
#                 ],
#                 [
#                     "2017-02-19",
#                     16792
#                 ],
#                 [
#                     "2017-02-20",
#                     23863
#                 ],
#                 [
#                     "2017-02-21",
#                     22620
#                 ],
#                 [
#                     "2017-02-22",
#                     19595
#                 ],
#                 [
#                     "2017-02-23",
#                     19506
#                 ],
#                 [
#                     "2017-02-24",
#                     6216
#                 ],
#                 [
#                     "2017-02-25",
#                     23014
#                 ],
#                 [
#                     "2017-02-26",
#                     24799
#                 ],
#                 [
#                     "2017-02-27",
#                     13092
#                 ],
#                 [
#                     "2017-02-28",
#                     9832
#                 ],
#                 [
#                     "2017-03-01",
#                     17403
#                 ],
#                 [
#                     "2017-03-02",
#                     6199
#                 ],
#                 [
#                     "2017-03-03",
#                     5285
#                 ],
#                 [
#                     "2017-03-04",
#                     21485
#                 ],
#                 [
#                     "2017-03-05",
#                     18211
#                 ],
#                 [
#                     "2017-03-06",
#                     9024
#                 ],
#                 [
#                     "2017-03-07",
#                     6912
#                 ],
#                 [
#                     "2017-03-08",
#                     14845
#                 ],
#                 [
#                     "2017-03-09",
#                     5808
#                 ],
#                 [
#                     "2017-03-10",
#                     10575
#                 ],
#                 [
#                     "2017-03

# %% [markdown]
# # 漏斗图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
funnel = Funnel()
funnel.add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
funnel.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
funnel.load_javascript()

# %%
funnel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1ec30bfb00a14988b90ff0f68b7230af" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1ec30bfb00a14988b90ff0f68b7230af = echarts.init(
#             document.getElementById('1ec30bfb00a14988b90ff0f68b7230af'), 'white', {renderer: 'canvas'});
#         var option_1ec30bfb00a14988b90ff0f68b7230af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 146
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 80
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8292\u679c",
#                 "\u67e0\u6aac",
#                 "\u96ea\u68a8",
#                 "\u8349\u8393",
#                 "\u8461\u8404",
#                 "\u897f\u74dc",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {
#                 "\u8349\u8393": true,
#                 "\u8292\u679c": true,
#                 "\u8461\u8404": true,
#                 "\u96ea\u68a8": true,
#                 "\u897f\u74dc": true,
#                 "\u67e0\u6aac": true,
#                 "\u8f66\u5398\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_1ec30bfb00a14988b90ff0f68b7230af.setOption(option_1ec30bfb00a14988b90ff0f68b7230af);
#     </script>
# </body>
# </html>

# %%
funnel=Funnel()
funnel.add("商品",[list(z) for z in zip(Faker.choose(), Faker.values())],label_opts=opts.LabelOpts(position="inside"),)
funnel.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Label（inside)"))
funnel.load_javascript()

# %%
funnel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7cb6ad156b244b238d2048cee5fd25c7" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_7cb6ad156b244b238d2048cee5fd25c7 = echarts.init(
#             document.getElementById('7cb6ad156b244b238d2048cee5fd25c7'), 'white', {renderer: 'canvas'});
#         var option_7cb6ad156b244b238d2048cee5fd25c7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 59
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7eff\u8336",
#                 "\u767e\u5a01",
#                 "\u5976\u8336",
#                 "\u9752\u5c9b",
#                 "\u96ea\u78a7",
#                 "\u53ef\u4e50",
#                 "\u6a59\u6c41"
#             ],
#             "selected": {
#                 "\u53ef\u4e50": true,
#                 "\u96ea\u78a7": true,
#                 "\u6a59\u6c41": true,
#                 "\u7eff\u8336": true,
#                 "\u5976\u8336": true,
#                 "\u767e\u5a01": true,
#                 "\u9752\u5c9b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-Label\uff08inside)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_7cb6ad156b244b238d2048cee5fd25c7.setOption(option_7cb6ad156b244b238d2048cee5fd25c7);
#     </script>
# </body>
# </html>

# %%
funnel=Funnel()
funnel.add("商品",[list(z) for z in zip(Faker.choose(), Faker.values())],sort_="ascending",label_opts=opts.LabelOpts(position="inside"),)
funnel.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Sort（ascending）"))
funnel.load_javascript()

# %%
funnel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="866f588dbd364a7fb9edb6a55de5da0a" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_866f588dbd364a7fb9edb6a55de5da0a = echarts.init(
#             document.getElementById('866f588dbd364a7fb9edb6a55de5da0a'), 'white', {renderer: 'canvas'});
#         var option_866f588dbd364a7fb9edb6a55de5da0a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 41
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8292\u679c",
#                 "\u67e0\u6aac",
#                 "\u96ea\u68a8",
#                 "\u8349\u8393",
#                 "\u8461\u8404",
#                 "\u897f\u74dc",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {
#                 "\u8349\u8393": true,
#                 "\u8292\u679c": true,
#                 "\u8461\u8404": true,
#                 "\u96ea\u68a8": true,
#                 "\u897f\u74dc": true,
#                 "\u67e0\u6aac": true,
#                 "\u8f66\u5398\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-Sort\uff08ascending\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_866f588dbd364a7fb9edb6a55de5da0a.setOption(option_866f588dbd364a7fb9edb6a55de5da0a);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 仪表盘

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page
gauge=Gauge()
gauge.add("", [("完成率", 66.6)])
gauge.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1b7849f887dd4ef9b1c18e3f4a090279" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1b7849f887dd4ef9b1c18e3f4a090279 = echarts.init(
#             document.getElementById('1b7849f887dd4ef9b1c18e3f4a090279'), 'white', {renderer: 'canvas'});
#         var option_1b7849f887dd4ef9b1c18e3f4a090279 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_1b7849f887dd4ef9b1c18e3f4a090279.setOption(option_1b7849f887dd4ef9b1c18e3f4a090279);
#     </script>
# </body>
# </html>

# %%
gauge = Gauge()
gauge.add(
            "业务指标",
            [("完成率", 55.5)],
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#67e0e3"), (0.7, "#37a2da"), (1, "#fd666d")], width=30
                )
            ),
        )
gauge.set_global_opts(
            title_opts=opts.TitleOpts(title="Gauge-不同颜色"),
            legend_opts=opts.LegendOpts(is_show=False),
        )
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="ae022463f0354d2395200cacd5fb7eb8" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_ae022463f0354d2395200cacd5fb7eb8 = echarts.init(
#             document.getElementById('ae022463f0354d2395200cacd5fb7eb8'), 'white', {renderer: 'canvas'});
#         var option_ae022463f0354d2395200cacd5fb7eb8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u4e0d\u540c\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_ae022463f0354d2395200cacd5fb7eb8.setOption(option_ae022463f0354d2395200cacd5fb7eb8);
#     </script>
# </body>
# </html>

# %%
gauge=Gauge()
gauge.add(
            "业务指标",
            [("完成率", 55.5)],
            split_number=5,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#67e0e3"), (0.7, "#37a2da"), (1, "#fd666d")], width=30
                )
            ),
    #label_opts=opts.LabelOpts(formatter="{value}"),
        )
gauge.set_global_opts(
            title_opts=opts.TitleOpts(title="Gauge-分割段数-Label"),
            legend_opts=opts.LegendOpts(is_show=False),
        )
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="c0d92a76490d435e93f1cc77643be3c0" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_c0d92a76490d435e93f1cc77643be3c0 = echarts.init(
#             document.getElementById('c0d92a76490d435e93f1cc77643be3c0'), 'white', {renderer: 'canvas'});
#         var option_c0d92a76490d435e93f1cc77643be3c0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 5,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u5206\u5272\u6bb5\u6570-Label",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_c0d92a76490d435e93f1cc77643be3c0.setOption(option_c0d92a76490d435e93f1cc77643be3c0);
#     </script>
# </body>
# </html>

# %%
gauge=Gauge()
gauge.add(
            "",
            [("完成率", 66.6)],
            title_label_opts=opts.LabelOpts(
                font_size=40, color="blue", font_family="Microsoft YaHei"
            ),
        )
gauge.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-改变轮盘内的字体"))
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5a78870143984d33a702cb5754981ece" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_5a78870143984d33a702cb5754981ece = echarts.init(
#             document.getElementById('5a78870143984d33a702cb5754981ece'), 'white', {renderer: 'canvas'});
#         var option_5a78870143984d33a702cb5754981ece = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "color": "blue",
#                 "margin": 8,
#                 "fontSize": 40,
#                 "fontFamily": "Microsoft YaHei"
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u6539\u53d8\u8f6e\u76d8\u5185\u7684\u5b57\u4f53",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_5a78870143984d33a702cb5754981ece.setOption(option_5a78870143984d33a702cb5754981ece);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 关系图(略)

# %%
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Graph, Page
nodes = [
        {"name": "结点1", "symbolSize": 10},
        {"name": "结点2", "symbolSize": 20},
        {"name": "结点3", "symbolSize": 30},
        {"name": "结点4", "symbolSize": 40},
        {"name": "结点5", "symbolSize": 50},
        {"name": "结点6", "symbolSize": 40},
        {"name": "结点7", "symbolSize": 30},
        {"name": "结点8", "symbolSize": 20},
    ]
links = []
for i in nodes:
        for j in nodes:
            links.append({"source": i.get("name"), "target": j.get("name")})
graph=Graph()
graph.add("", nodes, links, repulsion=8000)
graph.set_global_opts(title_opts=opts.TitleOpts(title="Graph-基本示例"))
graph.load_javascript()

# %%
graph.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="83ad0571ec65418cbc9db91af6827366" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_83ad0571ec65418cbc9db91af6827366 = echarts.init(
#             document.getElementById('83ad0571ec65418cbc9db91af6827366'), 'white', {renderer: 'canvas'});
#         var option_83ad0571ec65418cbc9db91af6827366 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 8000,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "\u7ed3\u70b91",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "\u7ed3\u70b92",
#                     "symbolSize": 20
#                 },
#                 {
#                     "name": "\u7ed3\u70b93",
#                     "symbolSize": 30
#                 },
#                 {
#                     "name": "\u7ed3\u70b94",
#                     "symbolSize": 40
#                 },
#                 {
#                     "name": "\u7ed3\u70b95",
#                     "symbolSize": 50
#                 },
#                 {
#                     "name": "\u7ed3\u70b96",
#                     "symbolSize": 40
#                 },
#                 {
#                     "name": "\u7ed3\u70b97",
#                     "symbolSize": 30
#                 },
#                 {
#                     "name": "\u7ed3\u70b98",
#                     "symbolSize": 20
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {

# %% [markdown]
# # 水球图(略)

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType
liquid=Liquid()
liquid.add("lq", [0.6, 0.7])
liquid.set_global_opts(title_opts=opts.TitleOpts(title="Liquid-基本示例"))
liquid.load_javascript()

# %%
liquid.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1027e0efc0954c59ac84c4e6438c0e55" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1027e0efc0954c59ac84c4e6438c0e55 = echarts.init(
#             document.getElementById('1027e0efc0954c59ac84c4e6438c0e55'), 'white', {renderer: 'canvas'});
#         var option_1027e0efc0954c59ac84c4e6438c0e55 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Liquid-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_1027e0efc0954c59ac84c4e6438c0e55.setOption(option_1027e0efc0954c59ac84c4e6438c0e55);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 平行坐标系

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Parallel
data = [
        [1, 91, 45, 125, 0.82, 34],
        [2, 65, 27, 78, 0.86, 45],
        [3, 83, 60, 84, 1.09, 73],
        [4, 109, 81, 121, 1.28, 68],
        [5, 106, 77, 114, 1.07, 55],
        [6, 109, 81, 121, 1.28, 68],
        [7, 106, 77, 114, 1.07, 55],
        [8, 89, 65, 78, 0.86, 51, 26],
        [9, 53, 33, 47, 0.64, 50, 17],
        [10, 80, 55, 80, 1.01, 75, 24],
        [11, 117, 81, 124, 1.03, 45],
    ]
parallel=Parallel()
parallel.add_schema(
            [
                {"dim": 0, "name": "data"},
                {"dim": 1, "name": "AQI"},
                {"dim": 2, "name": "PM2.5"},
                {"dim": 3, "name": "PM10"},
                {"dim": 4, "name": "CO"},
                {"dim": 5, "name": "NO2"},
            ]
        )
parallel.add("parallel", data)
parallel.set_global_opts(title_opts=opts.TitleOpts(title="Parallel-基本示例"))
parallel.load_javascript()

# %%
parallel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="433c33b50c58448f827bc28da3d06b08" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_433c33b50c58448f827bc28da3d06b08 = echarts.init(
#             document.getElementById('433c33b50c58448f827bc28da3d06b08'), 'white', {renderer: 'canvas'});
#         var option_433c33b50c58448f827bc28da3d06b08 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "parallel",
#             "coordinateSystem": "parallel",
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "name": "parallel",
#             "data": [
#                 [
#                     1,
#                     91,
#                     45,
#                     125,
#                     0.82,
#                     34
#                 ],
#                 [
#                     2,
#                     65,
#                     27,
#                     78,
#                     0.86,
#                     45
#                 ],
#                 [
#                     3,
#                     83,
#                     60,
#                     84,
#                     1.09,
#                     73
#                 ],
#                 [
#                     4,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68
#                 ],
#                 [
#                     5,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55
#                 ],
#                 [
#                     6,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68
#                 ],
#                 [
#                     7,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55
#                 ],
#                 [
#                     8,
#                     89,
#                     65,
#                     78,
#                     0.86,
#                     51,
#                     26
#                 ],
#                 [
#                     9,
#                     53,
#                     33,
#                     47,
#                     0.64,
#                     50,
#                     17
#                 ],
#                 [
#                     10,
#                     80,
#                     55,
#                     80,
#                     1.01,
#                     75,
#                     24
#                 ],
#                 [
#                     11,
#                     117,
#                     81,
#                     124,
#                     1.03,
#                     45
#                 ]
#             ],
#             "smooth": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "parallel"
#             ],
#             "selected": {
#                 "parallel": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "parallel": {
#         "left": "5%",
#         "right": "13%",
#         "bottom": "10%",
#         "top": "20%"
#     },
#     "parallelAxis": [
#         {
#             "dim": 0,
#             "name": "data"
#         },
#         {
#             "dim": 1,
#             "name": "AQI"
#         },
#         {
#             "dim": 2,
#             "name": "PM2.5"
#         },
#         {
#             "dim": 3,
#             "name": "PM10"
#         },
#         {
#             "dim": 4,
#             "name": "CO"
#         },
#         {
#             "dim": 5,
#             "name": "NO2"
#         }
#     ],
#     "title": [
#         {
#             "text": "Parallel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_433c33b50c58448f827bc28da3d06b08.setOption(option_433c33b50c58448f827bc28da3d06b08);
#     </script>
# </body>
# </html>

# %%
data = [
        [1, 91, 45, 125, 0.82, 34, 23, "良"],
        [2, 65, 27, 78, 0.86, 45, 29, "良"],
        [3, 83, 60, 84, 1.09, 73, 27, "良"],
        [4, 109, 81, 121, 1.28, 68, 51, "轻度污染"],
        [5, 106, 77, 114, 1.07, 55, 51, "轻度污染"],
        [6, 109, 81, 121, 1.28, 68, 51, "轻度污染"],
        [7, 106, 77, 114, 1.07, 55, 51, "轻度污染"],
        [8, 89, 65, 78, 0.86, 51, 26, "良"],
        [9, 53, 33, 47, 0.64, 50, 17, "良"],
        [10, 80, 55, 80, 1.01, 75, 24, "良"],
        [11, 117, 81, 124, 1.03, 45, 24, "轻度污染"],
        [12, 99, 71, 142, 1.1, 62, 42, "良"],
        [13, 95, 69, 130, 1.28, 74, 50, "良"],
        [14, 116, 87, 131, 1.47, 84, 40, "轻度污染"],
    ]
parallel=Parallel()
parallel.add_schema(
            [
                opts.ParallelAxisOpts(dim=0, name="data"),
                opts.ParallelAxisOpts(dim=1, name="AQI"),
                opts.ParallelAxisOpts(dim=2, name="PM2.5"),
                opts.ParallelAxisOpts(dim=3, name="PM10"),
                opts.ParallelAxisOpts(dim=4, name="CO"),
                opts.ParallelAxisOpts(dim=5, name="NO2"),
                opts.ParallelAxisOpts(dim=6, name="CO2"),
                opts.ParallelAxisOpts(
                    dim=7,
                    name="等级",
                    type_="category",
                    data=["优", "良", "轻度污染", "中度污染", "重度污染", "严重污染"],
                ),
            ]
        )
parallel.add("parallel", data)
parallel.set_global_opts(title_opts=opts.TitleOpts(title="Parallel-Category"))
parallel.load_javascript()

# %%
parallel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7c0e0d06f2fc4110986343d21672e225" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_7c0e0d06f2fc4110986343d21672e225 = echarts.init(
#             document.getElementById('7c0e0d06f2fc4110986343d21672e225'), 'white', {renderer: 'canvas'});
#         var option_7c0e0d06f2fc4110986343d21672e225 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "parallel",
#             "coordinateSystem": "parallel",
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "name": "parallel",
#             "data": [
#                 [
#                     1,
#                     91,
#                     45,
#                     125,
#                     0.82,
#                     34,
#                     23,
#                     "\u826f"
#                 ],
#                 [
#                     2,
#                     65,
#                     27,
#                     78,
#                     0.86,
#                     45,
#                     29,
#                     "\u826f"
#                 ],
#                 [
#                     3,
#                     83,
#                     60,
#                     84,
#                     1.09,
#                     73,
#                     27,
#                     "\u826f"
#                 ],
#                 [
#                     4,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     5,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     6,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     7,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     8,
#                     89,
#                     65,
#                     78,
#                     0.86,
#                     51,
#                     26,
#                     "\u826f"
#                 ],
#                 [
#                     9,
#                     53,
#                     33,
#                     47,
#                     0.64,
#                     50,
#                     17,
#                     "\u826f"
#                 ],
#                 [
#                     10,
#                     80,
#                     55,
#                     80,
#                     1.01,
#                     75,
#                     24,
#                     "\u826f"
#                 ],
#                 [
#                     11,
#                     117,
#                     81,
#                     124,
#                     1.03,
#                     45,
#                     24,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     12,
#                     99,
#                     71,
#                     142,
#                     1.1,
#                     62,
#                     42,
#                     "\u826f"
#                 ],
#                 [
#                     13,
#                     95,
#                     69,
#                     130,
#                     1.28,
#                     74,
#                     50,
#                     "\u826f"
#                 ],
#                 [
#                     14,
#                     116,
#                     87,
#                     131,
#                     1.47,
#                     84,
#                     40,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ]
#             ],
#             "smooth": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "parallel"
#             ],
#             "selected": {
#                 "parallel": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "parallel": {
#         "left": "5%",
#         "right": "13%",
#         "bottom": "10%",
#         "top": "20%"
#     },
#     "parallelAxis": [
#         {
#             "dim": 0,
#             "name": "data",
#             "scale": false
#         },
#         {
#             "dim": 1,
#             "name": "AQI",
#             "scale": false
#         },
#         {
#             "dim": 2,
#             "name": "PM2.5",
#             "scale": false
#         },
#         {
#             "dim": 3,
#             "name": "PM10",
#             "scale": false
#         },
#         {
#             "dim": 4,
#             "name": "CO",
#             "scale": false
#         },
#         {
#             "dim": 5,
#             "name": "NO2",
#             "scale": false
#         },
#         {
#             "dim": 6,
#             "name": "CO2",
#             "scale": false
#         },
#         {
#             "dim": 7,
#             "name": "\u7b49\u7ea7",
#             "data": [
#                 "\u4f18",
#                 "\u826f",
#                 "\u8f7b\u5ea6\u6c61\u67d3",
#                 "\u4e2d\u5ea6\u6c61\u67d3",
#                 "\u91cd\u5ea6\u6c61\u67d3",
#                 "\u4e25\u91cd\u6c61\u67d3"
#             ],
#             "type": "category",
#             "scale": false
#         }
#     ],
#     "title": [
#         {
#             "text": "Parallel-Category",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_7c0e0d06f2fc4110986343d21672e225.setOption(option_7c0e0d06f2fc4110986343d21672e225);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 饼图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Pie
pie=Pie()
pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a9910a6a463842c79157ca57f5a13a17" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_a9910a6a463842c79157ca57f5a13a17 = echarts.init(
#             document.getElementById('a9910a6a463842c79157ca57f5a13a17'), 'white', {renderer: 'canvas'});
#         var option_a9910a6a463842c79157ca57f5a13a17 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 101
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 64
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_a9910a6a463842c79157ca57f5a13a17.setOption(option_a9910a6a463842c79157ca57f5a13a17);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
pie.set_colors(["blue", "green", "yellow", "red", "pink", "orange", "purple"])
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-设置颜色"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="98013bba032142448e4c27aa31171f1d" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_98013bba032142448e4c27aa31171f1d = echarts.init(
#             document.getElementById('98013bba032142448e4c27aa31171f1d'), 'white', {renderer: 'canvas'});
#         var option_98013bba032142448e4c27aa31171f1d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "green",
#         "yellow",
#         "red",
#         "pink",
#         "orange",
#         "purple"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 44
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u8bbe\u7f6e\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_98013bba032142448e4c27aa31171f1d.setOption(option_98013bba032142448e4c27aa31171f1d);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            center=["35%", "50%"],
        )
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="Pie-调整位置"),
            legend_opts=opts.LegendOpts(pos_left="15%"),
        )
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="3019650dfbfb492e8411428f215f44b4" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_3019650dfbfb492e8411428f215f44b4 = echarts.init(
#             document.getElementById('3019650dfbfb492e8411428f215f44b4'), 'white', {renderer: 'canvas'});
#         var option_3019650dfbfb492e8411428f215f44b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 63
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 42
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "15%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u8c03\u6574\u4f4d\u7f6e",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_3019650dfbfb492e8411428f215f44b4.setOption(option_3019650dfbfb492e8411428f215f44b4);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["40%", "75%"],
        )
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="Pie-Radius"),
            legend_opts=opts.LegendOpts(
                orient="vertical", pos_top="15%", pos_left="2%"
            ),
        )
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="25309477c33543db9efb31edec5eaaf4" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_25309477c33543db9efb31edec5eaaf4 = echarts.init(
#             document.getElementById('25309477c33543db9efb31edec5eaaf4'), 'white', {renderer: 'canvas'});
#         var option_25309477c33543db9efb31edec5eaaf4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 131
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 85
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-Radius",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_25309477c33543db9efb31edec5eaaf4.setOption(option_25309477c33543db9efb31edec5eaaf4);
#     </script>
# </body>
# </html>

# %%
v = Faker.choose()
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["25%", "50%"],
            rosetype="radius",
            label_opts=opts.LabelOpts(is_show=False),
        )
pie.add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["75%", "50%"],
            rosetype="area",
        )
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="fb569923ac4a465aa628309c2e685a55" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_fb569923ac4a465aa628309c2e685a55 = echarts.init(
#             document.getElementById('fb569923ac4a465aa628309c2e685a55'), 'white', {renderer: 'canvas'});
#         var option_fb569923ac4a465aa628309c2e685a55 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 122
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 40
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 74
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 28
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_fb569923ac4a465aa628309c2e685a55.setOption(option_fb569923ac4a465aa628309c2e685a55);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [
                list(z)
                for z in zip(
                    Faker.choose() + Faker.choose() + Faker.choose(),
                    Faker.values() + Faker.values() + Faker.values(),
                )
            ],
            center=["40%", "50%"],
        )
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="Pie-Legend 滚动"),
            legend_opts=opts.LegendOpts(
                type_="scroll", pos_left="80%", orient="vertical"
            ),
        )
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b8a18ec574bc48debf8c12f2bbd8ba43" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_b8a18ec574bc48debf8c12f2bbd8ba43 = echarts.init(
#             document.getElementById('b8a18ec574bc48debf8c12f2bbd8ba43'), 'white', {renderer: 'canvas'});
#         var option_b8a18ec574bc48debf8c12f2bbd8ba43 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 58
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 142
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 145
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 91
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b",
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50",
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-Legend \u6eda\u52a8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_b8a18ec574bc48debf8c12f2bbd8ba43.setOption(option_b8a18ec574bc48debf8c12f2bbd8ba43);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["40%", "55%"],
            label_opts=opts.LabelOpts(
                position="outside",
                formatter="{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
                background_color="#eee",
                border_color="#aaa",
                border_width=1,
                border_radius=4,
                rich={
                    "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                    "abg": {
                        "backgroundColor": "#e3e3e3",
                        "width": "100%",
                        "align": "right",
                        "height": 22,
                        "borderRadius": [4, 4, 0, 0],
                    },
                    "hr": {
                        "borderColor": "#aaa",
                        "width": "100%",
                        "borderWidth": 0.5,
                        "height": 0,
                    },
                    "b": {"fontSize": 16, "lineHeight": 33},
                    "per": {
                        "color": "#eee",
                        "backgroundColor": "#334455",
                        "padding": [2, 4],
                        "borderRadius": 2,
                    },
                },
            ),
        )
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-富文本示例"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="9fd08876a34c484ab7bbf82d383ecf3c" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_9fd08876a34c484ab7bbf82d383ecf3c = echarts.init(
#             document.getElementById('9fd08876a34c484ab7bbf82d383ecf3c'), 'white', {renderer: 'canvas'});
#         var option_9fd08876a34c484ab7bbf82d383ecf3c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 90
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 110
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u5bcc\u6587\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_9fd08876a34c484ab7bbf82d383ecf3c.setOption(option_9fd08876a34c484ab7bbf82d383ecf3c);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 极坐标系
