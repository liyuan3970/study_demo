# %% [markdown]
# # 日历图

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar


begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [[str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)] for i in range((end - begin).days + 1) ]

calendar = Calendar()

calendar.add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
calendar.set_global_opts(
    title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
    visualmap_opts=opts.VisualMapOpts(
    max_=20000,
    min_=500,
    orient="horizontal",
    is_piecewise=True,
    pos_top="230px",
    pos_left="100px",), )
calendar.load_javascript()

# %%
calendar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1cd774633a854b8ebd242c384e495141" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1cd774633a854b8ebd242c384e495141 = echarts.init(
#             document.getElementById('1cd774633a854b8ebd242c384e495141'), 'white', {renderer: 'canvas'});
#         var option_1cd774633a854b8ebd242c384e495141 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2017-01-01",
#                     13066
#                 ],
#                 [
#                     "2017-01-02",
#                     12041
#                 ],
#                 [
#                     "2017-01-03",
#                     23530
#                 ],
#                 [
#                     "2017-01-04",
#                     14859
#                 ],
#                 [
#                     "2017-01-05",
#                     21070
#                 ],
#                 [
#                     "2017-01-06",
#                     21006
#                 ],
#                 [
#                     "2017-01-07",
#                     3622
#                 ],
#                 [
#                     "2017-01-08",
#                     14594
#                 ],
#                 [
#                     "2017-01-09",
#                     1307
#                 ],
#                 [
#                     "2017-01-10",
#                     17608
#                 ],
#                 [
#                     "2017-01-11",
#                     13917
#                 ],
#                 [
#                     "2017-01-12",
#                     21701
#                 ],
#                 [
#                     "2017-01-13",
#                     8894
#                 ],
#                 [
#                     "2017-01-14",
#                     19110
#                 ],
#                 [
#                     "2017-01-15",
#                     15676
#                 ],
#                 [
#                     "2017-01-16",
#                     22106
#                 ],
#                 [
#                     "2017-01-17",
#                     6264
#                 ],
#                 [
#                     "2017-01-18",
#                     10853
#                 ],
#                 [
#                     "2017-01-19",
#                     3925
#                 ],
#                 [
#                     "2017-01-20",
#                     15351
#                 ],
#                 [
#                     "2017-01-21",
#                     20767
#                 ],
#                 [
#                     "2017-01-22",
#                     10738
#                 ],
#                 [
#                     "2017-01-23",
#                     14117
#                 ],
#                 [
#                     "2017-01-24",
#                     20977
#                 ],
#                 [
#                     "2017-01-25",
#                     21641
#                 ],
#                 [
#                     "2017-01-26",
#                     12760
#                 ],
#                 [
#                     "2017-01-27",
#                     11459
#                 ],
#                 [
#                     "2017-01-28",
#                     24696
#                 ],
#                 [
#                     "2017-01-29",
#                     17893
#                 ],
#                 [
#                     "2017-01-30",
#                     3596
#                 ],
#                 [
#                     "2017-01-31",
#                     19138
#                 ],
#                 [
#                     "2017-02-01",
#                     13497
#                 ],
#                 [
#                     "2017-02-02",
#                     8061
#                 ],
#                 [
#                     "2017-02-03",
#                     7393
#                 ],
#                 [
#                     "2017-02-04",
#                     2310
#                 ],
#                 [
#                     "2017-02-05",
#                     8983
#                 ],
#                 [
#                     "2017-02-06",
#                     23098
#                 ],
#                 [
#                     "2017-02-07",
#                     3438
#                 ],
#                 [
#                     "2017-02-08",
#                     13164
#                 ],
#                 [
#                     "2017-02-09",
#                     24048
#                 ],
#                 [
#                     "2017-02-10",
#                     6666
#                 ],
#                 [
#                     "2017-02-11",
#                     1142
#                 ],
#                 [
#                     "2017-02-12",
#                     5240
#                 ],
#                 [
#                     "2017-02-13",
#                     21455
#                 ],
#                 [
#                     "2017-02-14",
#                     22779
#                 ],
#                 [
#                     "2017-02-15",
#                     23605
#                 ],
#                 [
#                     "2017-02-16",
#                     14340
#                 ],
#                 [
#                     "2017-02-17",
#                     5543
#                 ],
#                 [
#                     "2017-02-18",
#                     6326
#                 ],
#                 [
#                     "2017-02-19",
#                     16792
#                 ],
#                 [
#                     "2017-02-20",
#                     23863
#                 ],
#                 [
#                     "2017-02-21",
#                     22620
#                 ],
#                 [
#                     "2017-02-22",
#                     19595
#                 ],
#                 [
#                     "2017-02-23",
#                     19506
#                 ],
#                 [
#                     "2017-02-24",
#                     6216
#                 ],
#                 [
#                     "2017-02-25",
#                     23014
#                 ],
#                 [
#                     "2017-02-26",
#                     24799
#                 ],
#                 [
#                     "2017-02-27",
#                     13092
#                 ],
#                 [
#                     "2017-02-28",
#                     9832
#                 ],
#                 [
#                     "2017-03-01",
#                     17403
#                 ],
#                 [
#                     "2017-03-02",
#                     6199
#                 ],
#                 [
#                     "2017-03-03",
#                     5285
#                 ],
#                 [
#                     "2017-03-04",
#                     21485
#                 ],
#                 [
#                     "2017-03-05",
#                     18211
#                 ],
#                 [
#                     "2017-03-06",
#                     9024
#                 ],
#                 [
#                     "2017-03-07",
#                     6912
#                 ],
#                 [
#                     "2017-03-08",
#                     14845
#                 ],
#                 [
#                     "2017-03-09",
#                     5808
#                 ],
#                 [
#                     "2017-03-10",
#                     10575
#                 ],
#                 [
#                     "2017-03

# %% [markdown]
# # 漏斗图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
funnel = Funnel()
funnel.add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
funnel.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
funnel.load_javascript()

# %%
funnel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1ec30bfb00a14988b90ff0f68b7230af" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1ec30bfb00a14988b90ff0f68b7230af = echarts.init(
#             document.getElementById('1ec30bfb00a14988b90ff0f68b7230af'), 'white', {renderer: 'canvas'});
#         var option_1ec30bfb00a14988b90ff0f68b7230af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 146
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 80
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8292\u679c",
#                 "\u67e0\u6aac",
#                 "\u96ea\u68a8",
#                 "\u8349\u8393",
#                 "\u8461\u8404",
#                 "\u897f\u74dc",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {
#                 "\u8349\u8393": true,
#                 "\u8292\u679c": true,
#                 "\u8461\u8404": true,
#                 "\u96ea\u68a8": true,
#                 "\u897f\u74dc": true,
#                 "\u67e0\u6aac": true,
#                 "\u8f66\u5398\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_1ec30bfb00a14988b90ff0f68b7230af.setOption(option_1ec30bfb00a14988b90ff0f68b7230af);
#     </script>
# </body>
# </html>

# %%
funnel=Funnel()
funnel.add("商品",[list(z) for z in zip(Faker.choose(), Faker.values())],label_opts=opts.LabelOpts(position="inside"),)
funnel.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Label（inside)"))
funnel.load_javascript()

# %%
funnel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7cb6ad156b244b238d2048cee5fd25c7" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_7cb6ad156b244b238d2048cee5fd25c7 = echarts.init(
#             document.getElementById('7cb6ad156b244b238d2048cee5fd25c7'), 'white', {renderer: 'canvas'});
#         var option_7cb6ad156b244b238d2048cee5fd25c7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 59
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7eff\u8336",
#                 "\u767e\u5a01",
#                 "\u5976\u8336",
#                 "\u9752\u5c9b",
#                 "\u96ea\u78a7",
#                 "\u53ef\u4e50",
#                 "\u6a59\u6c41"
#             ],
#             "selected": {
#                 "\u53ef\u4e50": true,
#                 "\u96ea\u78a7": true,
#                 "\u6a59\u6c41": true,
#                 "\u7eff\u8336": true,
#                 "\u5976\u8336": true,
#                 "\u767e\u5a01": true,
#                 "\u9752\u5c9b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-Label\uff08inside)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_7cb6ad156b244b238d2048cee5fd25c7.setOption(option_7cb6ad156b244b238d2048cee5fd25c7);
#     </script>
# </body>
# </html>

# %%
funnel=Funnel()
funnel.add("商品",[list(z) for z in zip(Faker.choose(), Faker.values())],sort_="ascending",label_opts=opts.LabelOpts(position="inside"),)
funnel.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Sort（ascending）"))
funnel.load_javascript()

# %%
funnel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="866f588dbd364a7fb9edb6a55de5da0a" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_866f588dbd364a7fb9edb6a55de5da0a = echarts.init(
#             document.getElementById('866f588dbd364a7fb9edb6a55de5da0a'), 'white', {renderer: 'canvas'});
#         var option_866f588dbd364a7fb9edb6a55de5da0a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 69
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 41
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8292\u679c",
#                 "\u67e0\u6aac",
#                 "\u96ea\u68a8",
#                 "\u8349\u8393",
#                 "\u8461\u8404",
#                 "\u897f\u74dc",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {
#                 "\u8349\u8393": true,
#                 "\u8292\u679c": true,
#                 "\u8461\u8404": true,
#                 "\u96ea\u68a8": true,
#                 "\u897f\u74dc": true,
#                 "\u67e0\u6aac": true,
#                 "\u8f66\u5398\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-Sort\uff08ascending\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_866f588dbd364a7fb9edb6a55de5da0a.setOption(option_866f588dbd364a7fb9edb6a55de5da0a);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 仪表盘

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page
gauge=Gauge()
gauge.add("", [("完成率", 66.6)])
gauge.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1b7849f887dd4ef9b1c18e3f4a090279" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1b7849f887dd4ef9b1c18e3f4a090279 = echarts.init(
#             document.getElementById('1b7849f887dd4ef9b1c18e3f4a090279'), 'white', {renderer: 'canvas'});
#         var option_1b7849f887dd4ef9b1c18e3f4a090279 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_1b7849f887dd4ef9b1c18e3f4a090279.setOption(option_1b7849f887dd4ef9b1c18e3f4a090279);
#     </script>
# </body>
# </html>

# %%
gauge = Gauge()
gauge.add(
            "业务指标",
            [("完成率", 55.5)],
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#67e0e3"), (0.7, "#37a2da"), (1, "#fd666d")], width=30
                )
            ),
        )
gauge.set_global_opts(
            title_opts=opts.TitleOpts(title="Gauge-不同颜色"),
            legend_opts=opts.LegendOpts(is_show=False),
        )
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="ae022463f0354d2395200cacd5fb7eb8" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_ae022463f0354d2395200cacd5fb7eb8 = echarts.init(
#             document.getElementById('ae022463f0354d2395200cacd5fb7eb8'), 'white', {renderer: 'canvas'});
#         var option_ae022463f0354d2395200cacd5fb7eb8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u4e0d\u540c\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_ae022463f0354d2395200cacd5fb7eb8.setOption(option_ae022463f0354d2395200cacd5fb7eb8);
#     </script>
# </body>
# </html>

# %%
gauge=Gauge()
gauge.add(
            "业务指标",
            [("完成率", 55.5)],
            split_number=5,
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(
                    color=[(0.3, "#67e0e3"), (0.7, "#37a2da"), (1, "#fd666d")], width=30
                )
            ),
    #label_opts=opts.LabelOpts(formatter="{value}"),
        )
gauge.set_global_opts(
            title_opts=opts.TitleOpts(title="Gauge-分割段数-Label"),
            legend_opts=opts.LegendOpts(is_show=False),
        )
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="c0d92a76490d435e93f1cc77643be3c0" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_c0d92a76490d435e93f1cc77643be3c0 = echarts.init(
#             document.getElementById('c0d92a76490d435e93f1cc77643be3c0'), 'white', {renderer: 'canvas'});
#         var option_c0d92a76490d435e93f1cc77643be3c0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 5,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u5206\u5272\u6bb5\u6570-Label",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_c0d92a76490d435e93f1cc77643be3c0.setOption(option_c0d92a76490d435e93f1cc77643be3c0);
#     </script>
# </body>
# </html>

# %%
gauge=Gauge()
gauge.add(
            "",
            [("完成率", 66.6)],
            title_label_opts=opts.LabelOpts(
                font_size=40, color="blue", font_family="Microsoft YaHei"
            ),
        )
gauge.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-改变轮盘内的字体"))
gauge.load_javascript()

# %%
gauge.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5a78870143984d33a702cb5754981ece" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_5a78870143984d33a702cb5754981ece = echarts.init(
#             document.getElementById('5a78870143984d33a702cb5754981ece'), 'white', {renderer: 'canvas'});
#         var option_5a78870143984d33a702cb5754981ece = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "color": "blue",
#                 "margin": 8,
#                 "fontSize": 40,
#                 "fontFamily": "Microsoft YaHei"
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u6539\u53d8\u8f6e\u76d8\u5185\u7684\u5b57\u4f53",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_5a78870143984d33a702cb5754981ece.setOption(option_5a78870143984d33a702cb5754981ece);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 关系图(略)

# %%
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Graph, Page
nodes = [
        {"name": "结点1", "symbolSize": 10},
        {"name": "结点2", "symbolSize": 20},
        {"name": "结点3", "symbolSize": 30},
        {"name": "结点4", "symbolSize": 40},
        {"name": "结点5", "symbolSize": 50},
        {"name": "结点6", "symbolSize": 40},
        {"name": "结点7", "symbolSize": 30},
        {"name": "结点8", "symbolSize": 20},
    ]
links = []
for i in nodes:
        for j in nodes:
            links.append({"source": i.get("name"), "target": j.get("name")})
graph=Graph()
graph.add("", nodes, links, repulsion=8000)
graph.set_global_opts(title_opts=opts.TitleOpts(title="Graph-基本示例"))
graph.load_javascript()

# %%
graph.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="83ad0571ec65418cbc9db91af6827366" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_83ad0571ec65418cbc9db91af6827366 = echarts.init(
#             document.getElementById('83ad0571ec65418cbc9db91af6827366'), 'white', {renderer: 'canvas'});
#         var option_83ad0571ec65418cbc9db91af6827366 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 8000,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "\u7ed3\u70b91",
#                     "symbolSize": 10
#                 },
#                 {
#                     "name": "\u7ed3\u70b92",
#                     "symbolSize": 20
#                 },
#                 {
#                     "name": "\u7ed3\u70b93",
#                     "symbolSize": 30
#                 },
#                 {
#                     "name": "\u7ed3\u70b94",
#                     "symbolSize": 40
#                 },
#                 {
#                     "name": "\u7ed3\u70b95",
#                     "symbolSize": 50
#                 },
#                 {
#                     "name": "\u7ed3\u70b96",
#                     "symbolSize": 40
#                 },
#                 {
#                     "name": "\u7ed3\u70b97",
#                     "symbolSize": 30
#                 },
#                 {
#                     "name": "\u7ed3\u70b98",
#                     "symbolSize": 20
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b91",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b92",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b93",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b96"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b97"
#                 },
#                 {
#                     "source": "\u7ed3\u70b94",
#                     "target": "\u7ed3\u70b98"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b91"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b92"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b93"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b94"
#                 },
#                 {
#                     "source": "\u7ed3\u70b95",
#                     "target": "\u7ed3\u70b95"
#                 },
#                 {

# %% [markdown]
# # 水球图(略)

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType
liquid=Liquid()
liquid.add("lq", [0.6, 0.7])
liquid.set_global_opts(title_opts=opts.TitleOpts(title="Liquid-基本示例"))
liquid.load_javascript()

# %%
liquid.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="1027e0efc0954c59ac84c4e6438c0e55" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_1027e0efc0954c59ac84c4e6438c0e55 = echarts.init(
#             document.getElementById('1027e0efc0954c59ac84c4e6438c0e55'), 'white', {renderer: 'canvas'});
#         var option_1027e0efc0954c59ac84c4e6438c0e55 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Liquid-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_1027e0efc0954c59ac84c4e6438c0e55.setOption(option_1027e0efc0954c59ac84c4e6438c0e55);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 平行坐标系

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Parallel
data = [
        [1, 91, 45, 125, 0.82, 34],
        [2, 65, 27, 78, 0.86, 45],
        [3, 83, 60, 84, 1.09, 73],
        [4, 109, 81, 121, 1.28, 68],
        [5, 106, 77, 114, 1.07, 55],
        [6, 109, 81, 121, 1.28, 68],
        [7, 106, 77, 114, 1.07, 55],
        [8, 89, 65, 78, 0.86, 51, 26],
        [9, 53, 33, 47, 0.64, 50, 17],
        [10, 80, 55, 80, 1.01, 75, 24],
        [11, 117, 81, 124, 1.03, 45],
    ]
parallel=Parallel()
parallel.add_schema(
            [
                {"dim": 0, "name": "data"},
                {"dim": 1, "name": "AQI"},
                {"dim": 2, "name": "PM2.5"},
                {"dim": 3, "name": "PM10"},
                {"dim": 4, "name": "CO"},
                {"dim": 5, "name": "NO2"},
            ]
        )
parallel.add("parallel", data)
parallel.set_global_opts(title_opts=opts.TitleOpts(title="Parallel-基本示例"))
parallel.load_javascript()

# %%
parallel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="433c33b50c58448f827bc28da3d06b08" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_433c33b50c58448f827bc28da3d06b08 = echarts.init(
#             document.getElementById('433c33b50c58448f827bc28da3d06b08'), 'white', {renderer: 'canvas'});
#         var option_433c33b50c58448f827bc28da3d06b08 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "parallel",
#             "coordinateSystem": "parallel",
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "name": "parallel",
#             "data": [
#                 [
#                     1,
#                     91,
#                     45,
#                     125,
#                     0.82,
#                     34
#                 ],
#                 [
#                     2,
#                     65,
#                     27,
#                     78,
#                     0.86,
#                     45
#                 ],
#                 [
#                     3,
#                     83,
#                     60,
#                     84,
#                     1.09,
#                     73
#                 ],
#                 [
#                     4,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68
#                 ],
#                 [
#                     5,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55
#                 ],
#                 [
#                     6,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68
#                 ],
#                 [
#                     7,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55
#                 ],
#                 [
#                     8,
#                     89,
#                     65,
#                     78,
#                     0.86,
#                     51,
#                     26
#                 ],
#                 [
#                     9,
#                     53,
#                     33,
#                     47,
#                     0.64,
#                     50,
#                     17
#                 ],
#                 [
#                     10,
#                     80,
#                     55,
#                     80,
#                     1.01,
#                     75,
#                     24
#                 ],
#                 [
#                     11,
#                     117,
#                     81,
#                     124,
#                     1.03,
#                     45
#                 ]
#             ],
#             "smooth": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "parallel"
#             ],
#             "selected": {
#                 "parallel": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "parallel": {
#         "left": "5%",
#         "right": "13%",
#         "bottom": "10%",
#         "top": "20%"
#     },
#     "parallelAxis": [
#         {
#             "dim": 0,
#             "name": "data"
#         },
#         {
#             "dim": 1,
#             "name": "AQI"
#         },
#         {
#             "dim": 2,
#             "name": "PM2.5"
#         },
#         {
#             "dim": 3,
#             "name": "PM10"
#         },
#         {
#             "dim": 4,
#             "name": "CO"
#         },
#         {
#             "dim": 5,
#             "name": "NO2"
#         }
#     ],
#     "title": [
#         {
#             "text": "Parallel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_433c33b50c58448f827bc28da3d06b08.setOption(option_433c33b50c58448f827bc28da3d06b08);
#     </script>
# </body>
# </html>

# %%
data = [
        [1, 91, 45, 125, 0.82, 34, 23, "良"],
        [2, 65, 27, 78, 0.86, 45, 29, "良"],
        [3, 83, 60, 84, 1.09, 73, 27, "良"],
        [4, 109, 81, 121, 1.28, 68, 51, "轻度污染"],
        [5, 106, 77, 114, 1.07, 55, 51, "轻度污染"],
        [6, 109, 81, 121, 1.28, 68, 51, "轻度污染"],
        [7, 106, 77, 114, 1.07, 55, 51, "轻度污染"],
        [8, 89, 65, 78, 0.86, 51, 26, "良"],
        [9, 53, 33, 47, 0.64, 50, 17, "良"],
        [10, 80, 55, 80, 1.01, 75, 24, "良"],
        [11, 117, 81, 124, 1.03, 45, 24, "轻度污染"],
        [12, 99, 71, 142, 1.1, 62, 42, "良"],
        [13, 95, 69, 130, 1.28, 74, 50, "良"],
        [14, 116, 87, 131, 1.47, 84, 40, "轻度污染"],
    ]
parallel=Parallel()
parallel.add_schema(
            [
                opts.ParallelAxisOpts(dim=0, name="data"),
                opts.ParallelAxisOpts(dim=1, name="AQI"),
                opts.ParallelAxisOpts(dim=2, name="PM2.5"),
                opts.ParallelAxisOpts(dim=3, name="PM10"),
                opts.ParallelAxisOpts(dim=4, name="CO"),
                opts.ParallelAxisOpts(dim=5, name="NO2"),
                opts.ParallelAxisOpts(dim=6, name="CO2"),
                opts.ParallelAxisOpts(
                    dim=7,
                    name="等级",
                    type_="category",
                    data=["优", "良", "轻度污染", "中度污染", "重度污染", "严重污染"],
                ),
            ]
        )
parallel.add("parallel", data)
parallel.set_global_opts(title_opts=opts.TitleOpts(title="Parallel-Category"))
parallel.load_javascript()

# %%
parallel.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="7c0e0d06f2fc4110986343d21672e225" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_7c0e0d06f2fc4110986343d21672e225 = echarts.init(
#             document.getElementById('7c0e0d06f2fc4110986343d21672e225'), 'white', {renderer: 'canvas'});
#         var option_7c0e0d06f2fc4110986343d21672e225 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "parallel",
#             "coordinateSystem": "parallel",
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "name": "parallel",
#             "data": [
#                 [
#                     1,
#                     91,
#                     45,
#                     125,
#                     0.82,
#                     34,
#                     23,
#                     "\u826f"
#                 ],
#                 [
#                     2,
#                     65,
#                     27,
#                     78,
#                     0.86,
#                     45,
#                     29,
#                     "\u826f"
#                 ],
#                 [
#                     3,
#                     83,
#                     60,
#                     84,
#                     1.09,
#                     73,
#                     27,
#                     "\u826f"
#                 ],
#                 [
#                     4,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     5,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     6,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     7,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     8,
#                     89,
#                     65,
#                     78,
#                     0.86,
#                     51,
#                     26,
#                     "\u826f"
#                 ],
#                 [
#                     9,
#                     53,
#                     33,
#                     47,
#                     0.64,
#                     50,
#                     17,
#                     "\u826f"
#                 ],
#                 [
#                     10,
#                     80,
#                     55,
#                     80,
#                     1.01,
#                     75,
#                     24,
#                     "\u826f"
#                 ],
#                 [
#                     11,
#                     117,
#                     81,
#                     124,
#                     1.03,
#                     45,
#                     24,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     12,
#                     99,
#                     71,
#                     142,
#                     1.1,
#                     62,
#                     42,
#                     "\u826f"
#                 ],
#                 [
#                     13,
#                     95,
#                     69,
#                     130,
#                     1.28,
#                     74,
#                     50,
#                     "\u826f"
#                 ],
#                 [
#                     14,
#                     116,
#                     87,
#                     131,
#                     1.47,
#                     84,
#                     40,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ]
#             ],
#             "smooth": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "parallel"
#             ],
#             "selected": {
#                 "parallel": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "parallel": {
#         "left": "5%",
#         "right": "13%",
#         "bottom": "10%",
#         "top": "20%"
#     },
#     "parallelAxis": [
#         {
#             "dim": 0,
#             "name": "data",
#             "scale": false
#         },
#         {
#             "dim": 1,
#             "name": "AQI",
#             "scale": false
#         },
#         {
#             "dim": 2,
#             "name": "PM2.5",
#             "scale": false
#         },
#         {
#             "dim": 3,
#             "name": "PM10",
#             "scale": false
#         },
#         {
#             "dim": 4,
#             "name": "CO",
#             "scale": false
#         },
#         {
#             "dim": 5,
#             "name": "NO2",
#             "scale": false
#         },
#         {
#             "dim": 6,
#             "name": "CO2",
#             "scale": false
#         },
#         {
#             "dim": 7,
#             "name": "\u7b49\u7ea7",
#             "data": [
#                 "\u4f18",
#                 "\u826f",
#                 "\u8f7b\u5ea6\u6c61\u67d3",
#                 "\u4e2d\u5ea6\u6c61\u67d3",
#                 "\u91cd\u5ea6\u6c61\u67d3",
#                 "\u4e25\u91cd\u6c61\u67d3"
#             ],
#             "type": "category",
#             "scale": false
#         }
#     ],
#     "title": [
#         {
#             "text": "Parallel-Category",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_7c0e0d06f2fc4110986343d21672e225.setOption(option_7c0e0d06f2fc4110986343d21672e225);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 饼图

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Pie
pie=Pie()
pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="a9910a6a463842c79157ca57f5a13a17" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_a9910a6a463842c79157ca57f5a13a17 = echarts.init(
#             document.getElementById('a9910a6a463842c79157ca57f5a13a17'), 'white', {renderer: 'canvas'});
#         var option_a9910a6a463842c79157ca57f5a13a17 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 101
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 64
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_a9910a6a463842c79157ca57f5a13a17.setOption(option_a9910a6a463842c79157ca57f5a13a17);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
pie.set_colors(["blue", "green", "yellow", "red", "pink", "orange", "purple"])
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-设置颜色"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="98013bba032142448e4c27aa31171f1d" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_98013bba032142448e4c27aa31171f1d = echarts.init(
#             document.getElementById('98013bba032142448e4c27aa31171f1d'), 'white', {renderer: 'canvas'});
#         var option_98013bba032142448e4c27aa31171f1d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "green",
#         "yellow",
#         "red",
#         "pink",
#         "orange",
#         "purple"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 44
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u8bbe\u7f6e\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_98013bba032142448e4c27aa31171f1d.setOption(option_98013bba032142448e4c27aa31171f1d);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            center=["35%", "50%"],
        )
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="Pie-调整位置"),
            legend_opts=opts.LegendOpts(pos_left="15%"),
        )
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="3019650dfbfb492e8411428f215f44b4" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_3019650dfbfb492e8411428f215f44b4 = echarts.init(
#             document.getElementById('3019650dfbfb492e8411428f215f44b4'), 'white', {renderer: 'canvas'});
#         var option_3019650dfbfb492e8411428f215f44b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 63
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 42
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "35%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "15%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u8c03\u6574\u4f4d\u7f6e",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_3019650dfbfb492e8411428f215f44b4.setOption(option_3019650dfbfb492e8411428f215f44b4);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["40%", "75%"],
        )
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="Pie-Radius"),
            legend_opts=opts.LegendOpts(
                orient="vertical", pos_top="15%", pos_left="2%"
            ),
        )
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="25309477c33543db9efb31edec5eaaf4" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_25309477c33543db9efb31edec5eaaf4 = echarts.init(
#             document.getElementById('25309477c33543db9efb31edec5eaaf4'), 'white', {renderer: 'canvas'});
#         var option_25309477c33543db9efb31edec5eaaf4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 131
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 85
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-Radius",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_25309477c33543db9efb31edec5eaaf4.setOption(option_25309477c33543db9efb31edec5eaaf4);
#     </script>
# </body>
# </html>

# %%
v = Faker.choose()
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["25%", "50%"],
            rosetype="radius",
            label_opts=opts.LabelOpts(is_show=False),
        )
pie.add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["75%", "50%"],
            rosetype="area",
        )
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="fb569923ac4a465aa628309c2e685a55" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_fb569923ac4a465aa628309c2e685a55 = echarts.init(
#             document.getElementById('fb569923ac4a465aa628309c2e685a55'), 'white', {renderer: 'canvas'});
#         var option_fb569923ac4a465aa628309c2e685a55 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 122
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 40
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 74
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 28
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_fb569923ac4a465aa628309c2e685a55.setOption(option_fb569923ac4a465aa628309c2e685a55);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [
                list(z)
                for z in zip(
                    Faker.choose() + Faker.choose() + Faker.choose(),
                    Faker.values() + Faker.values() + Faker.values(),
                )
            ],
            center=["40%", "50%"],
        )
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="Pie-Legend 滚动"),
            legend_opts=opts.LegendOpts(
                type_="scroll", pos_left="80%", orient="vertical"
            ),
        )
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b8a18ec574bc48debf8c12f2bbd8ba43" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_b8a18ec574bc48debf8c12f2bbd8ba43 = echarts.init(
#             document.getElementById('b8a18ec574bc48debf8c12f2bbd8ba43'), 'white', {renderer: 'canvas'});
#         var option_b8a18ec574bc48debf8c12f2bbd8ba43 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 58
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 142
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 93
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 145
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 91
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b",
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50",
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-Legend \u6eda\u52a8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_b8a18ec574bc48debf8c12f2bbd8ba43.setOption(option_b8a18ec574bc48debf8c12f2bbd8ba43);
#     </script>
# </body>
# </html>

# %%
pie=Pie()
pie.add(
            "",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["40%", "55%"],
            label_opts=opts.LabelOpts(
                position="outside",
                formatter="{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
                background_color="#eee",
                border_color="#aaa",
                border_width=1,
                border_radius=4,
                rich={
                    "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                    "abg": {
                        "backgroundColor": "#e3e3e3",
                        "width": "100%",
                        "align": "right",
                        "height": 22,
                        "borderRadius": [4, 4, 0, 0],
                    },
                    "hr": {
                        "borderColor": "#aaa",
                        "width": "100%",
                        "borderWidth": 0.5,
                        "height": 0,
                    },
                    "b": {"fontSize": 16, "lineHeight": 33},
                    "per": {
                        "color": "#eee",
                        "backgroundColor": "#334455",
                        "padding": [2, 4],
                        "borderRadius": 2,
                    },
                },
            ),
        )
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-富文本示例"))
pie.load_javascript()

# %%
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="9fd08876a34c484ab7bbf82d383ecf3c" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_9fd08876a34c484ab7bbf82d383ecf3c = echarts.init(
#             document.getElementById('9fd08876a34c484ab7bbf82d383ecf3c'), 'white', {renderer: 'canvas'});
#         var option_9fd08876a34c484ab7bbf82d383ecf3c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 90
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 110
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u5bcc\u6587\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_9fd08876a34c484ab7bbf82d383ecf3c.setOption(option_9fd08876a34c484ab7bbf82d383ecf3c);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 极坐标系

# %%
import math
import random

from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Polar
data = [(i, random.randint(1, 100)) for i in range(101)]

polar=Polar()
polar.add("", data, type_="scatter", label_opts=opts.LabelOpts(is_show=False))
polar.set_global_opts(title_opts=opts.TitleOpts(title="Polar-Scatter0"))
polar.load_javascript()

# %%
polar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="fbd5d75038c04c5a80bbfac154a3fd33" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_fbd5d75038c04c5a80bbfac154a3fd33 = echarts.init(
#             document.getElementById('fbd5d75038c04c5a80bbfac154a3fd33'), 'white', {renderer: 'canvas'});
#         var option_fbd5d75038c04c5a80bbfac154a3fd33 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0,
#                     38
#                 ],
#                 [
#                     1,
#                     100
#                 ],
#                 [
#                     2,
#                     44
#                 ],
#                 [
#                     3,
#                     1
#                 ],
#                 [
#                     4,
#                     48
#                 ],
#                 [
#                     5,
#                     53
#                 ],
#                 [
#                     6,
#                     18
#                 ],
#                 [
#                     7,
#                     86
#                 ],
#                 [
#                     8,
#                     71
#                 ],
#                 [
#                     9,
#                     50
#                 ],
#                 [
#                     10,
#                     74
#                 ],
#                 [
#                     11,
#                     78
#                 ],
#                 [
#                     12,
#                     59
#                 ],
#                 [
#                     13,
#                     24
#                 ],
#                 [
#                     14,
#                     58
#                 ],
#                 [
#                     15,
#                     86
#                 ],
#                 [
#                     16,
#                     23
#                 ],
#                 [
#                     17,
#                     88
#                 ],
#                 [
#                     18,
#                     46
#                 ],
#                 [
#                     19,
#                     35
#                 ],
#                 [
#                     20,
#                     68
#                 ],
#                 [
#                     21,
#                     79
#                 ],
#                 [
#                     22,
#                     51
#                 ],
#                 [
#                     23,
#                     64
#                 ],
#                 [
#                     24,
#                     1
#                 ],
#                 [
#                     25,
#                     16
#                 ],
#                 [
#                     26,
#                     37
#                 ],
#                 [
#                     27,
#                     12
#                 ],
#                 [
#                     28,
#                     35
#                 ],
#                 [
#                     29,
#                     81
#                 ],
#                 [
#                     30,
#                     70
#                 ],
#                 [
#                     31,
#                     27
#                 ],
#                 [
#                     32,
#                     12
#                 ],
#                 [
#                     33,
#                     63
#                 ],
#                 [
#                     34,
#                     95
#                 ],
#                 [
#                     35,
#                     95
#                 ],
#                 [
#                     36,
#                     71
#                 ],
#                 [
#                     37,
#                     57
#                 ],
#                 [
#                     38,
#                     8
#                 ],
#                 [
#                     39,
#                     35
#                 ],
#                 [
#                     40,
#                     1
#                 ],
#                 [
#                     41,
#                     38
#                 ],
#                 [
#                     42,
#                     61
#                 ],
#                 [
#                     43,
#                     13
#                 ],
#                 [
#                     44,
#                     7
#                 ],
#                 [
#                     45,
#                     50
#                 ],
#                 [
#                     46,
#                     42
#                 ],
#                 [
#                     47,
#                     20
#                 ],
#                 [
#                     48,
#                     22
#                 ],
#                 [
#                     49,
#                     2
#                 ],
#                 [
#                     50,
#                     95
#                 ],
#                 [
#                     51,
#                     88
#                 ],
#                 [
#                     52,
#                     21
#                 ],
#                 [
#                     53,
#                     69
#                 ],
#                 [
#                     54,
#                     86
#                 ],
#                 [
#                     55,
#                     69
#                 ],
#                 [
#                     56,
#                     47
#                 ],
#                 [
#                     57,
#                     57
#                 ],
#                 [
#                     58,
#                     41
#                 ],
#                 [
#                     59,
#                     81
#                 ],
#                 [
#                     60,
#                     19
#                 ],
#                 [
#                     61,
#                     90
#                 ],
#                 [
#                     62,
#                     56
#                 ],
#                 [
#                     63,
#                     62
#                 ],
#                 [
#                     64,
#                     77
#                 ],
#                 [
#                     65,
#                     43
#                 ],
#                 [
#                     66,
#                     86
#                 ],
#                 [
#                     67,
#                     53
#                 ],
#                 [
#                     68,
#                     98
#                 ],
#                 [
#                     69,
#                     14
#                 ],
#                 [
#                     70,
#                     14
#                 ],
#                 [
#                     71,
#                     55
#                 ],
#                 [
#                     72,
#                     76
#                 ],
#                 [
#                     73,
#                     85
#                 ],
#                 [
#                     74,
#                     23
#                 ],
#                 [
#                     75,
#                     81
#                 ],
#                 [
#                     76,
#                     1
#                 ],
#                 [
#                     77,
#                     98
#                 ],
#                 [
#                     78,
#                     39
#                 ],
#                 [
#                     79,
#                     3

# %%
polar=Polar()
polar.add("", [(10, random.randint(1, 100)) for i in range(300)], type_="scatter")
polar.add("", [(11, random.randint(1, 100)) for i in range(300)], type_="scatter")
polar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
polar.set_global_opts(title_opts=opts.TitleOpts(title="Polar-Scatter1"))
polar.load_javascript()

# %%
polar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="0c49da767b1f4cd7b47ac4a3d6c86cfe" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_0c49da767b1f4cd7b47ac4a3d6c86cfe = echarts.init(
#             document.getElementById('0c49da767b1f4cd7b47ac4a3d6c86cfe'), 'white', {renderer: 'canvas'});
#         var option_0c49da767b1f4cd7b47ac4a3d6c86cfe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 [
#                     10,
#                     3
#                 ],
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     10,
#                     52
#                 ],
#                 [
#                     10,
#                     87
#                 ],
#                 [
#                     10,
#                     29
#                 ],
#                 [
#                     10,
#                     81
#                 ],
#                 [
#                     10,
#                     2
#                 ],
#                 [
#                     10,
#                     15
#                 ],
#                 [
#                     10,
#                     90
#                 ],
#                 [
#                     10,
#                     84
#                 ],
#                 [
#                     10,
#                     41
#                 ],
#                 [
#                     10,
#                     58
#                 ],
#                 [
#                     10,
#                     11
#                 ],
#                 [
#                     10,
#                     46
#                 ],
#                 [
#                     10,
#                     94
#                 ],
#                 [
#                     10,
#                     38
#                 ],
#                 [
#                     10,
#                     80
#                 ],
#                 [
#                     10,
#                     38
#                 ],
#                 [
#                     10,
#                     94
#                 ],
#                 [
#                     10,
#                     46
#                 ],
#                 [
#                     10,
#                     31
#                 ],
#                 [
#                     10,
#                     21
#                 ],
#                 [
#                     10,
#                     67
#                 ],
#                 [
#                     10,
#                     98
#                 ],
#                 [
#                     10,
#                     77
#                 ],
#                 [
#                     10,
#                     97
#                 ],
#                 [
#                     10,
#                     61
#                 ],
#                 [
#                     10,
#                     32
#                 ],
#                 [
#                     10,
#                     24
#                 ],
#                 [
#                     10,
#                     95
#                 ],
#                 [
#                     10,
#                     20
#                 ],
#                 [
#                     10,
#                     43
#                 ],
#                 [
#                     10,
#                     45
#                 ],
#                 [
#                     10,
#                     54
#                 ],
#                 [
#                     10,
#                     86
#                 ],
#                 [
#                     10,
#                     41
#                 ],
#                 [
#                     10,
#                     44
#                 ],
#                 [
#                     10,
#                     71
#                 ],
#                 [
#                     10,
#                     68
#                 ],
#                 [
#                     10,
#                     87
#                 ],
#                 [
#                     10,
#                     70
#                 ],
#                 [
#                     10,
#                     39
#                 ],
#                 [
#                     10,
#                     56
#                 ],
#                 [
#                     10,
#                     48
#                 ],
#                 [
#                     10,
#                     46
#                 ],
#                 [
#                     10,
#                     4
#                 ],
#                 [
#                     10,
#                     86
#                 ],
#                 [
#                     10,
#                     49
#                 ],
#                 [
#                     10,
#                     57
#                 ],
#                 [
#                     10,
#                     37
#                 ],
#                 [
#                     10,
#                     40
#                 ],
#                 [
#                     10,
#                     73
#                 ],
#                 [
#                     10,
#                     67
#                 ],
#                 [
#                     10,
#                     9
#                 ],
#                 [
#                     10,
#                     1
#                 ],
#                 [
#                     10,
#                     1
#                 ],
#                 [
#                     10,
#                     48
#                 ],
#                 [
#                     10,
#                     63
#                 ],
#                 [
#                     10,
#                     59
#                 ],
#                 [
#                     10,
#                     81
#                 ],
#                 [
#                     10,
#                     92
#                 ],
#                 [
#                     10,
#                     33
#                 ],
#                 [
#                     10,
#                     11
#                 ],
#                 [
#                     10,
#                     71
#                 ],
#                 [
#                     10,
#                     57
#                 ],
#                 [
#                     10,
#                     18
#                 ],
#                 [
#                     10,
#                     100
#                 ],
#                 [
#                     10,
#                     6
#                 ],
#                 [
#                     10,
#                     98
#                 ],
#                 [
#                     10,
#                     91
#                 ],
#                 [
#                     10,
#                     4
#                 ],
#                 [
#                     10,
#                     33
#                 ],
#                 [
#                     10,
#                     80
#                 ],
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     10,
#                     64
#                 ],
#                 [
#                     10,
#                     43
#                 ],
#                 [
#                     10,
#                     76
#                 ],
#                 [
#                     10,
#                     26
#                 ],
#                 [
#                     10,

# %%
data = [(i, random.randint(1, 100)) for i in range(10)]
ploar=Polar()
ploar.add(
            "",
            data,
            type_="effectScatter",
            effect_opts=opts.EffectOpts(scale=10, period=5),
            label_opts=opts.LabelOpts(is_show=False),
        )
polar.set_global_opts(title_opts=opts.TitleOpts(title="Polar-EffectScatter"))
polar.load_javascript()

# %%
polar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="8a0b6aa2b2224620a9a94c3f3ff81c54" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_8a0b6aa2b2224620a9a94c3f3ff81c54 = echarts.init(
#             document.getElementById('8a0b6aa2b2224620a9a94c3f3ff81c54'), 'white', {renderer: 'canvas'});
#         var option_8a0b6aa2b2224620a9a94c3f3ff81c54 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 [
#                     10,
#                     3
#                 ],
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     10,
#                     52
#                 ],
#                 [
#                     10,
#                     87
#                 ],
#                 [
#                     10,
#                     29
#                 ],
#                 [
#                     10,
#                     81
#                 ],
#                 [
#                     10,
#                     2
#                 ],
#                 [
#                     10,
#                     15
#                 ],
#                 [
#                     10,
#                     90
#                 ],
#                 [
#                     10,
#                     84
#                 ],
#                 [
#                     10,
#                     41
#                 ],
#                 [
#                     10,
#                     58
#                 ],
#                 [
#                     10,
#                     11
#                 ],
#                 [
#                     10,
#                     46
#                 ],
#                 [
#                     10,
#                     94
#                 ],
#                 [
#                     10,
#                     38
#                 ],
#                 [
#                     10,
#                     80
#                 ],
#                 [
#                     10,
#                     38
#                 ],
#                 [
#                     10,
#                     94
#                 ],
#                 [
#                     10,
#                     46
#                 ],
#                 [
#                     10,
#                     31
#                 ],
#                 [
#                     10,
#                     21
#                 ],
#                 [
#                     10,
#                     67
#                 ],
#                 [
#                     10,
#                     98
#                 ],
#                 [
#                     10,
#                     77
#                 ],
#                 [
#                     10,
#                     97
#                 ],
#                 [
#                     10,
#                     61
#                 ],
#                 [
#                     10,
#                     32
#                 ],
#                 [
#                     10,
#                     24
#                 ],
#                 [
#                     10,
#                     95
#                 ],
#                 [
#                     10,
#                     20
#                 ],
#                 [
#                     10,
#                     43
#                 ],
#                 [
#                     10,
#                     45
#                 ],
#                 [
#                     10,
#                     54
#                 ],
#                 [
#                     10,
#                     86
#                 ],
#                 [
#                     10,
#                     41
#                 ],
#                 [
#                     10,
#                     44
#                 ],
#                 [
#                     10,
#                     71
#                 ],
#                 [
#                     10,
#                     68
#                 ],
#                 [
#                     10,
#                     87
#                 ],
#                 [
#                     10,
#                     70
#                 ],
#                 [
#                     10,
#                     39
#                 ],
#                 [
#                     10,
#                     56
#                 ],
#                 [
#                     10,
#                     48
#                 ],
#                 [
#                     10,
#                     46
#                 ],
#                 [
#                     10,
#                     4
#                 ],
#                 [
#                     10,
#                     86
#                 ],
#                 [
#                     10,
#                     49
#                 ],
#                 [
#                     10,
#                     57
#                 ],
#                 [
#                     10,
#                     37
#                 ],
#                 [
#                     10,
#                     40
#                 ],
#                 [
#                     10,
#                     73
#                 ],
#                 [
#                     10,
#                     67
#                 ],
#                 [
#                     10,
#                     9
#                 ],
#                 [
#                     10,
#                     1
#                 ],
#                 [
#                     10,
#                     1
#                 ],
#                 [
#                     10,
#                     48
#                 ],
#                 [
#                     10,
#                     63
#                 ],
#                 [
#                     10,
#                     59
#                 ],
#                 [
#                     10,
#                     81
#                 ],
#                 [
#                     10,
#                     92
#                 ],
#                 [
#                     10,
#                     33
#                 ],
#                 [
#                     10,
#                     11
#                 ],
#                 [
#                     10,
#                     71
#                 ],
#                 [
#                     10,
#                     57
#                 ],
#                 [
#                     10,
#                     18
#                 ],
#                 [
#                     10,
#                     100
#                 ],
#                 [
#                     10,
#                     6
#                 ],
#                 [
#                     10,
#                     98
#                 ],
#                 [
#                     10,
#                     91
#                 ],
#                 [
#                     10,
#                     4
#                 ],
#                 [
#                     10,
#                     33
#                 ],
#                 [
#                     10,
#                     80
#                 ],
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     10,
#                     64
#                 ],
#                 [
#                     10,
#                     43
#                 ],
#                 [
#                     10,
#                     76
#                 ],
#                 [
#                     10,
#                     26
#                 ],
#                 [
#                     10,

# %%
polar=Polar()
polar.add_schema(
            radiusaxis_opts=opts.RadiusAxisOpts(data=Faker.week, type_="category")
        )
polar.add("A", [1, 2, 3, 4, 3, 5, 1], type_="bar", stack="stack0")
polar.add("B", [2, 4, 6, 1, 2, 3, 1], type_="bar", stack="stack0")
polar.add("C", [1, 2, 3, 4, 1, 2, 5], type_="bar", stack="stack0")
polar.set_global_opts(title_opts=opts.TitleOpts(title="Polar-RadiusAxis"))
polar.load_javascript()

# %%
polar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="d432a47c840c4ad183dda5d3645bd31b" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_d432a47c840c4ad183dda5d3645bd31b = echarts.init(
#             document.getElementById('d432a47c840c4ad183dda5d3645bd31b'), 'white', {renderer: 'canvas'});
#         var option_d432a47c840c4ad183dda5d3645bd31b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 1,
#                 2,
#                 3,
#                 4,
#                 3,
#                 5,
#                 1
#             ],
#             "stack": "stack0",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 2,
#                 4,
#                 6,
#                 1,
#                 2,
#                 3,
#                 1
#             ],
#             "stack": "stack0",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "bar",
#             "name": "C",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 1,
#                 2,
#                 3,
#                 4,
#                 1,
#                 2,
#                 5
#             ],
#             "stack": "stack0",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true,
#                 "C": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radiusAxis": {
#         "type": "category",
#         "data": [
#             "\u5468\u4e00",
#             "\u5468\u4e8c",
#             "\u5468\u4e09",
#             "\u5468\u56db",
#             "\u5468\u4e94",
#             "\u5468\u516d",
#             "\u5468\u65e5"
#         ],
#         "scale": false
#     },
#     "angleAxis": {
#         "clockwise": false
#     },
#     "polar": {},
#     "title": [
#         {
#             "text": "Polar-RadiusAxis",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_d432a47c840c4ad183dda5d3645bd31b.setOption(option_d432a47c840c4ad183dda5d3645bd31b);
#     </script>
# </body>
# </html>

# %%
polar=Polar()
polar.add_schema(
            angleaxis_opts=opts.AngleAxisOpts(data=Faker.week, type_="category")
        )
polar.add("A", [1, 2, 3, 4, 3, 5, 1], type_="bar", stack="stack0")
polar.add("B", [2, 4, 6, 1, 2, 3, 1], type_="bar", stack="stack0")
polar.add("C", [1, 2, 3, 4, 1, 2, 5], type_="bar", stack="stack0")
polar.set_global_opts(title_opts=opts.TitleOpts(title="Polar-AngleAxis"))
polar.load_javascript()

# %%
polar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="6e4af18866eb4ea5b354d818021d8751" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_6e4af18866eb4ea5b354d818021d8751 = echarts.init(
#             document.getElementById('6e4af18866eb4ea5b354d818021d8751'), 'white', {renderer: 'canvas'});
#         var option_6e4af18866eb4ea5b354d818021d8751 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 1,
#                 2,
#                 3,
#                 4,
#                 3,
#                 5,
#                 1
#             ],
#             "stack": "stack0",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 2,
#                 4,
#                 6,
#                 1,
#                 2,
#                 3,
#                 1
#             ],
#             "stack": "stack0",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "bar",
#             "name": "C",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 1,
#                 2,
#                 3,
#                 4,
#                 1,
#                 2,
#                 5
#             ],
#             "stack": "stack0",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true,
#                 "C": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radiusAxis": {
#         "scale": false
#     },
#     "angleAxis": {
#         "data": [
#             "\u5468\u4e00",
#             "\u5468\u4e8c",
#             "\u5468\u4e09",
#             "\u5468\u56db",
#             "\u5468\u4e94",
#             "\u5468\u516d",
#             "\u5468\u65e5"
#         ],
#         "clockwise": false,
#         "type": "category"
#     },
#     "polar": {},
#     "title": [
#         {
#             "text": "Polar-AngleAxis",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_6e4af18866eb4ea5b354d818021d8751.setOption(option_6e4af18866eb4ea5b354d818021d8751);
#     </script>
# </body>
# </html>

# %%
data = []
for i in range(361):
    t = i / 180 * math.pi
    r = math.sin(2 * t) * math.cos(2 * t)
    data.append([r, i])
polar=Polar()
polar.add_schema(angleaxis_opts=opts.AngleAxisOpts(start_angle=0, min_=0))
polar.add("flower", data, label_opts=opts.LabelOpts(is_show=False))
polar.set_global_opts(title_opts=opts.TitleOpts(title="Polar-Flower"))
polar.load_javascript()

# %%
polar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="0d8cd3c2e3264a3ea5a596f65cc7cafd" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_0d8cd3c2e3264a3ea5a596f65cc7cafd = echarts.init(
#             document.getElementById('0d8cd3c2e3264a3ea5a596f65cc7cafd'), 'white', {renderer: 'canvas'});
#         var option_0d8cd3c2e3264a3ea5a596f65cc7cafd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "flower",
#             "coordinateSystem": "polar",
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0.0,
#                     0
#                 ],
#                 [
#                     0.03487823687206265,
#                     1
#                 ],
#                 [
#                     0.06958655048003272,
#                     2
#                 ],
#                 [
#                     0.10395584540887964,
#                     3
#                 ],
#                 [
#                     0.13781867790849958,
#                     4
#                 ],
#                 [
#                     0.17101007166283433,
#                     5
#                 ],
#                 [
#                     0.2033683215379001,
#                     6
#                 ],
#                 [
#                     0.2347357813929454,
#                     7
#                 ],
#                 [
#                     0.26495963211660245,
#                     8
#                 ],
#                 [
#                     0.2938926261462365,
#                     9
#                 ],
#                 [
#                     0.3213938048432697,
#                     10
#                 ],
#                 [
#                     0.3473291852294986,
#                     11
#                 ],
#                 [
#                     0.37157241273869707,
#                     12
#                 ],
#                 [
#                     0.394005376803361,
#                     13
#                 ],
#                 [
#                     0.41451878627752087,
#                     14
#                 ],
#                 [
#                     0.4330127018922193,
#                     15
#                 ],
#                 [
#                     0.44939702314958346,
#                     16
#                 ],
#                 [
#                     0.4635919272833937,
#                     17
#                 ],
#                 [
#                     0.4755282581475768,
#                     18
#                 ],
#                 [
#                     0.48514786313799824,
#                     19
#                 ],
#                 [
#                     0.49240387650610395,
#                     20
#                 ],
#                 [
#                     0.4972609476841367,
#                     21
#                 ],
#                 [
#                     0.4996954135095479,
#                     22
#                 ],
#                 [
#                     0.4996954135095479,
#                     23
#                 ],
#                 [
#                     0.49726094768413664,
#                     24
#                 ],
#                 [
#                     0.49240387650610407,
#                     25
#                 ],
#                 [
#                     0.48514786313799824,
#                     26
#                 ],
#                 [
#                     0.4755282581475768,
#                     27
#                 ],
#                 [
#                     0.4635919272833937,
#                     28
#                 ],
#                 [
#                     0.44939702314958346,
#                     29
#                 ],
#                 [
#                     0.4330127018922194,
#                     30
#                 ],
#                 [
#                     0.41451878627752087,
#                     31
#                 ],
#                 [
#                     0.39400537680336106,
#                     32
#                 ],
#                 [
#                     0.37157241273869723,
#                     33
#                 ],
#                 [
#                     0.34732918522949874,
#                     34
#                 ],
#                 [
#                     0.32139380484326974,
#                     35
#                 ],
#                 [
#                     0.29389262614623657,
#                     36
#                 ],
#                 [
#                     0.26495963211660245,
#                     37
#                 ],
#                 [
#                     0.23473578139294535,
#                     38
#                 ],
#                 [
#                     0.20336832153790002,
#                     39
#                 ],
#                 [
#                     0.1710100716628344,
#                     40
#                 ],
#                 [
#                     0.1378186779084996,
#                     41
#                 ],
#                 [
#                     0.10395584540887964,
#                     42
#                 ],
#                 [
#                     0.06958655048003265,
#                     43
#                 ],
#                 [
#                     0.03487823687206276,
#                     44
#                 ],
#                 [
#                     6.123233995736766e-17,
#                     45
#                 ],
#                 [
#                     -0.034878236872062415,
#                     46
#                 ],
#                 [
#                     -0.06958655048003275,
#                     47
#                 ],
#                 [
#                     -0.10395584540887953,
#                     48
#                 ],
#                 [
#                     -0.1378186779084993,
#                     49
#                 ],
#                 [
#                     -0.17101007166283433,
#                     50
#                 ],
#                 [
#                     -0.2033683215378999,
#                     51
#                 ],
#                 [
#                     -0.23473578139294524,
#                     52
#                 ],
#                 [
#                     -0.26495963211660234,
#                     53
#                 ],
#                 [
#                     -0.2938926261462365,
#                     54
#                 ],
#                 [
#                     -0.3213938048432697,
#                     55
#                 ],
#                 [
#                     -0.3473291852294987,
#                     56
#                 ],
#                 [
#                     -0.371572412738697,
#                     57
#                 ],
#                 [
#                     -0.39400537680336106,
#                     58
#                 ],
#                 [
#                     -0.4145187862775207,
#                     59
#                 ],
#                 [
#                     -0.4330127018922192,
#                     60
#                 ],
#                 [
#                     -0.4493970231495834,
#                     61
#                 ],
#                 [
#                     -0.4635919272833936,
#                     62
#                 ],
#                 [
#                     -0.4755282581475767,
#                     63
#                 ],
#                 [
#                     -0.4851478631379983,
#                     64
#                 ],
#                 [
#                     -0.49240387650610407,
#                     65
#                 ],
#                 [

# %% [markdown]
# # 雷达图

# %%
from pyecharts import options as opts
from pyecharts.charts import Radar


v1 = [[4300, 10000, 28000, 35000, 50000, 19000]]
v2 = [[5000, 14000, 28000, 31000, 42000, 21000]]



radar=Radar()
radar.add_schema(
            schema=[
                opts.RadarIndicatorItem(name="销售", max_=6500),
                opts.RadarIndicatorItem(name="管理", max_=16000),
                opts.RadarIndicatorItem(name="信息技术", max_=30000),
                opts.RadarIndicatorItem(name="客服", max_=38000),
                opts.RadarIndicatorItem(name="研发", max_=52000),
                opts.RadarIndicatorItem(name="市场", max_=25000),
            ]
        )
radar.add("预算分配", v1)
radar.add("实际开销", v2)
radar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
radar.set_global_opts(title_opts=opts.TitleOpts(title="Radar-基本示例"))
radar.load_javascript()

# %%
radar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="413c66bcd7594cf385fe6afa1e10648c" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_413c66bcd7594cf385fe6afa1e10648c = echarts.init(
#             document.getElementById('413c66bcd7594cf385fe6afa1e10648c'), 'white', {renderer: 'canvas'});
#         var option_413c66bcd7594cf385fe6afa1e10648c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u9884\u7b97\u5206\u914d",
#             "data": [
#                 [
#                     4300,
#                     10000,
#                     28000,
#                     35000,
#                     50000,
#                     19000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5b9e\u9645\u5f00\u9500",
#             "data": [
#                 [
#                     5000,
#                     14000,
#                     28000,
#                     31000,
#                     42000,
#                     21000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9884\u7b97\u5206\u914d",
#                 "\u5b9e\u9645\u5f00\u9500"
#             ],
#             "selected": {
#                 "\u9884\u7b97\u5206\u914d": true,
#                 "\u5b9e\u9645\u5f00\u9500": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u9500\u552e",
#                 "max": 6500
#             },
#             {
#                 "name": "\u7ba1\u7406",
#                 "max": 16000
#             },
#             {
#                 "name": "\u4fe1\u606f\u6280\u672f",
#                 "max": 30000
#             },
#             {
#                 "name": "\u5ba2\u670d",
#                 "max": 38000
#             },
#             {
#                 "name": "\u7814\u53d1",
#                 "max": 52000
#             },
#             {
#                 "name": "\u5e02\u573a",
#                 "max": 25000
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "Radar-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_413c66bcd7594cf385fe6afa1e10648c.setOption(option_413c66bcd7594cf385fe6afa1e10648c);
#     </script>
# </body>
# </html>

# %%
value_bj = [
        [55, 9, 56, 0.46, 18, 6, 1],
        [25, 11, 21, 0.65, 34, 9, 2],
        [56, 7, 63, 0.3, 14, 5, 3],
        [33, 7, 29, 0.33, 16, 6, 4],
        [42, 24, 44, 0.76, 40, 16, 5],
        [82, 58, 90, 1.77, 68, 33, 6],
        [74, 49, 77, 1.46, 48, 27, 7],
        [78, 55, 80, 1.29, 59, 29, 8],
        [267, 216, 280, 4.8, 108, 64, 9],
        [185, 127, 216, 2.52, 61, 27, 10],
        [39, 19, 38, 0.57, 31, 15, 11],
        [41, 11, 40, 0.43, 21, 7, 12],
    ]
value_sh = [
        [91, 45, 125, 0.82, 34, 23, 1],
        [65, 27, 78, 0.86, 45, 29, 2],
        [83, 60, 84, 1.09, 73, 27, 3],
        [109, 81, 121, 1.28, 68, 51, 4],
        [106, 77, 114, 1.07, 55, 51, 5],
        [109, 81, 121, 1.28, 68, 51, 6],
        [106, 77, 114, 1.07, 55, 51, 7],
        [89, 65, 78, 0.86, 51, 26, 8],
        [53, 33, 47, 0.64, 50, 17, 9],
        [80, 55, 80, 1.01, 75, 24, 10],
        [117, 81, 124, 1.03, 45, 24, 11],
        [99, 71, 142, 1.1, 62, 42, 12],
    ]
c_schema = [
        {"name": "AQI", "max": 300, "min": 5},
        {"name": "PM2.5", "max": 250, "min": 20},
        {"name": "PM10", "max": 300, "min": 5},
        {"name": "CO", "max": 5},
        {"name": "NO2", "max": 200},
        {"name": "SO2", "max": 100},
    ]
radar=Radar()
radar.add_schema(schema=c_schema, shape="circle")
radar.add("北京", value_bj, color="#f9713c")
radar.add("上海", value_sh, color="#b3e4a1")
radar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
radar.set_global_opts(title_opts=opts.TitleOpts(title="Radar-空气质量"))
radar.load_javascript()

# %%
radar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="608b27e837e14cc1abab63c9adf6570b" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_608b27e837e14cc1abab63c9adf6570b = echarts.init(
#             document.getElementById('608b27e837e14cc1abab63c9adf6570b'), 'white', {renderer: 'canvas'});
#         var option_608b27e837e14cc1abab63c9adf6570b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u5317\u4eac",
#             "data": [
#                 [
#                     55,
#                     9,
#                     56,
#                     0.46,
#                     18,
#                     6,
#                     1
#                 ],
#                 [
#                     25,
#                     11,
#                     21,
#                     0.65,
#                     34,
#                     9,
#                     2
#                 ],
#                 [
#                     56,
#                     7,
#                     63,
#                     0.3,
#                     14,
#                     5,
#                     3
#                 ],
#                 [
#                     33,
#                     7,
#                     29,
#                     0.33,
#                     16,
#                     6,
#                     4
#                 ],
#                 [
#                     42,
#                     24,
#                     44,
#                     0.76,
#                     40,
#                     16,
#                     5
#                 ],
#                 [
#                     82,
#                     58,
#                     90,
#                     1.77,
#                     68,
#                     33,
#                     6
#                 ],
#                 [
#                     74,
#                     49,
#                     77,
#                     1.46,
#                     48,
#                     27,
#                     7
#                 ],
#                 [
#                     78,
#                     55,
#                     80,
#                     1.29,
#                     59,
#                     29,
#                     8
#                 ],
#                 [
#                     267,
#                     216,
#                     280,
#                     4.8,
#                     108,
#                     64,
#                     9
#                 ],
#                 [
#                     185,
#                     127,
#                     216,
#                     2.52,
#                     61,
#                     27,
#                     10
#                 ],
#                 [
#                     39,
#                     19,
#                     38,
#                     0.57,
#                     31,
#                     15,
#                     11
#                 ],
#                 [
#                     41,
#                     11,
#                     40,
#                     0.43,
#                     21,
#                     7,
#                     12
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#f9713c"
#                 }
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u4e0a\u6d77",
#             "data": [
#                 [
#                     91,
#                     45,
#                     125,
#                     0.82,
#                     34,
#                     23,
#                     1
#                 ],
#                 [
#                     65,
#                     27,
#                     78,
#                     0.86,
#                     45,
#                     29,
#                     2
#                 ],
#                 [
#                     83,
#                     60,
#                     84,
#                     1.09,
#                     73,
#                     27,
#                     3
#                 ],
#                 [
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     4
#                 ],
#                 [
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     5
#                 ],
#                 [
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     6
#                 ],
#                 [
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     7
#                 ],
#                 [
#                     89,
#                     65,
#                     78,
#                     0.86,
#                     51,
#                     26,
#                     8
#                 ],
#                 [
#                     53,
#                     33,
#                     47,
#                     0.64,
#                     50,
#                     17,
#                     9
#                 ],
#                 [
#                     80,
#                     55,
#                     80,
#                     1.01,
#                     75,
#                     24,
#                     10
#                 ],
#                 [
#                     117,
#                     81,
#                     124,
#                     1.03,
#                     45,
#                     24,
#                     11
#                 ],
#                 [
#                     99,
#                     71,
#                     142,
#                     1.1,
#                     62,
#                     42,
#                     12
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#b3e4a1"
#                 }
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77"
#             ],
#             "selected": {
#                 "\u5317\u4eac": true,
#                 "\u4e0a\u6d77": true
#             },
#             "show": true,
#             "padding": 5,
#             "it

# %% [markdown]
# # 桑基图

# %%
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Page, Sankey


nodes = [
        {"name": "category1"},
        {"name": "category2"},
        {"name": "category3"},
        {"name": "category4"},
        {"name": "category5"},
        {"name": "category6"},
    ]

links = [
        {"source": "category1", "target": "category2", "value": 10},
        {"source": "category2", "target": "category3", "value": 15},
        {"source": "category3", "target": "category4", "value": 20},
        {"source": "category5", "target": "category6", "value": 25},
    ]
sankey=Sankey()
sankey.add(
            "sankey",
            nodes,
            links,
            linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
            label_opts=opts.LabelOpts(position="right"),
        )
sankey.set_global_opts(title_opts=opts.TitleOpts(title="Sankey-基本示例"))
sankey.load_javascript()

# %%
sankey.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5bce6b162d184667b94feb7151acc780" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_5bce6b162d184667b94feb7151acc780 = echarts.init(
#             document.getElementById('5bce6b162d184667b94feb7151acc780'), 'white', {renderer: 'canvas'});
#         var option_5bce6b162d184667b94feb7151acc780 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "category1"
#                 },
#                 {
#                     "name": "category2"
#                 },
#                 {
#                     "name": "category3"
#                 },
#                 {
#                     "name": "category4"
#                 },
#                 {
#                     "name": "category5"
#                 },
#                 {
#                     "name": "category6"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "category1",
#                     "target": "category2",
#                     "value": 10
#                 },
#                 {
#                     "source": "category2",
#                     "target": "category3",
#                     "value": 15
#                 },
#                 {
#                     "source": "category3",
#                     "target": "category4",
#                     "value": 20
#                 },
#                 {
#                     "source": "category5",
#                     "target": "category6",
#                     "value": 25
#                 }
#             ],
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 0.2,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "source"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sankey"
#             ],
#             "selected": {
#                 "sankey": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Sankey-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_5bce6b162d184667b94feb7151acc780.setOption(option_5bce6b162d184667b94feb7151acc780);
#     </script>
# </body>
# </html>

# %%
from pyecharts import options as opts
from pyecharts.charts import Sunburst

data = [
        opts.SunburstItem(
            name="Grandpa",
            children=[
                opts.SunburstItem(
                    name="Uncle Leo",
                    value=15,
                    children=[
                        opts.SunburstItem(name="Cousin Jack", value=2),
                        opts.SunburstItem(
                            name="Cousin Mary",
                            value=5,
                            children=[opts.SunburstItem(name="Jackson", value=2)],
                        ),
                        opts.SunburstItem(name="Cousin Ben", value=4),
                    ],
                ),
                opts.SunburstItem(
                    name="Father",
                    value=10,
                    children=[
                        opts.SunburstItem(name="Me", value=5),
                        opts.SunburstItem(name="Brother Peter", value=1),
                    ],
                ),
            ],
        ),
        opts.SunburstItem(
            name="Nancy",
            children=[
                opts.SunburstItem(
                    name="Uncle Nike",
                    children=[
                        opts.SunburstItem(name="Cousin Betty", value=1),
                        opts.SunburstItem(name="Cousin Jenny", value=2),
                    ],
                )
            ],
        ),
    ]

sunburst=Sunburst()
sunburst.add(series_name="", data_pair=data, radius=[0, "90%"])
sunburst.set_global_opts(title_opts=opts.TitleOpts(title="Sunburst-基本示例"))
sunburst.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}"))
sunburst.load_javascript()

# %%
sunburst.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="ce963c5660c1422db0e0860563c57038" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_ce963c5660c1422db0e0860563c57038 = echarts.init(
#             document.getElementById('ce963c5660c1422db0e0860563c57038'), 'white', {renderer: 'canvas'});
#         var option_ce963c5660c1422db0e0860563c57038 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sunburst",
#             "data": [
#                 {
#                     "name": "Grandpa",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "value": 15,
#                             "name": "Uncle Leo",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 2,
#                                     "name": "Cousin Jack",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 5,
#                                     "name": "Cousin Mary",
#                                     "target": "blank",
#                                     "children": [
#                                         {
#                                             "value": 2,
#                                             "name": "Jackson",
#                                             "target": "blank"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "value": 4,
#                                     "name": "Cousin Ben",
#                                     "target": "blank"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 10,
#                             "name": "Father",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 5,
#                                     "name": "Me",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 1,
#                                     "name": "Brother Peter",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Nancy",
#                     "target": "blank",
#                     "children": [
#                         {
#                             "name": "Uncle Nike",
#                             "target": "blank",
#                             "children": [
#                                 {
#                                     "value": 1,
#                                     "name": "Cousin Betty",
#                                     "target": "blank"
#                                 },
#                                 {
#                                     "value": 2,
#                                     "name": "Cousin Jenny",
#                                     "target": "blank"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": [
#                 0,
#                 "90%"
#             ],
#             "highlightPolicy": "descendant",
#             "nodeClick": "rootToNode",
#             "sort": "desc",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Sunburst-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_ce963c5660c1422db0e0860563c57038.setOption(option_ce963c5660c1422db0e0860563c57038);
#     </script>
# </body>
# </html>

# %% [markdown]
# # 河流图

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, ThemeRiver

data = [
        ["2015/11/08", 10, "DQ"],
        ["2015/11/09", 15, "DQ"],
        ["2015/11/10", 35, "DQ"],
        ["2015/11/14", 7, "DQ"],
        ["2015/11/15", 2, "DQ"],
        ["2015/11/16", 17, "DQ"],
        ["2015/11/17", 33, "DQ"],
        ["2015/11/18", 40, "DQ"],
        ["2015/11/19", 32, "DQ"],
        ["2015/11/20", 26, "DQ"],
        ["2015/11/08", 35, "TY"],
        ["2015/11/09", 36, "TY"],
        ["2015/11/10", 37, "TY"],
        ["2015/11/11", 22, "TY"],
        ["2015/11/12", 24, "TY"],
        ["2015/11/13", 26, "TY"],
        ["2015/11/14", 34, "TY"],
        ["2015/11/15", 21, "TY"],
        ["2015/11/16", 18, "TY"],
        ["2015/11/17", 45, "TY"],
        ["2015/11/18", 32, "TY"],
        ["2015/11/19", 35, "TY"],
        ["2015/11/20", 30, "TY"],
        ["2015/11/08", 21, "SS"],
        ["2015/11/09", 25, "SS"],
        ["2015/11/10", 27, "SS"],
        ["2015/11/11", 23, "SS"],
        ["2015/11/12", 24, "SS"],
        ["2015/11/13", 21, "SS"],
        ["2015/11/14", 35, "SS"],
        ["2015/11/15", 39, "SS"],
        ["2015/11/16", 40, "SS"],
        ["2015/11/17", 36, "SS"],
        ["2015/11/18", 33, "SS"],
        ["2015/11/19", 43, "SS"],
        ["2015/11/20", 40, "SS"],
        ["2015/11/14", 7, "QG"],
        ["2015/11/15", 2, "QG"],
        ["2015/11/16", 17, "QG"],
        ["2015/11/17", 33, "QG"],
        ["2015/11/18", 40, "QG"],
        ["2015/11/19", 32, "QG"],
        ["2015/11/20", 26, "QG"],
        ["2015/11/21", 35, "QG"],
        ["2015/11/22", 40, "QG"],
        ["2015/11/23", 32, "QG"],
        ["2015/11/24", 26, "QG"],
        ["2015/11/25", 22, "QG"],
        ["2015/11/08", 10, "SY"],
        ["2015/11/09", 15, "SY"],
        ["2015/11/10", 35, "SY"],
        ["2015/11/11", 38, "SY"],
        ["2015/11/12", 22, "SY"],
        ["2015/11/13", 16, "SY"],
        ["2015/11/14", 7, "SY"],
        ["2015/11/15", 2, "SY"],
        ["2015/11/16", 17, "SY"],
        ["2015/11/17", 33, "SY"],
        ["2015/11/18", 40, "SY"],
        ["2015/11/19", 32, "SY"],
        ["2015/11/20", 26, "SY"],
        ["2015/11/21", 35, "SY"],
        ["2015/11/22", 4, "SY"],
        ["2015/11/23", 32, "SY"],
        ["2015/11/24", 26, "SY"],
        ["2015/11/25", 22, "SY"],
        ["2015/11/08", 10, "DD"],
        ["2015/11/09", 15, "DD"],
        ["2015/11/10", 35, "DD"],
        ["2015/11/11", 38, "DD"],
        ["2015/11/12", 22, "DD"],
        ["2015/11/13", 16, "DD"],
        ["2015/11/14", 7, "DD"],
        ["2015/11/15", 2, "DD"],
        ["2015/11/16", 17, "DD"],
        ["2015/11/17", 33, "DD"],
        ["2015/11/18", 4, "DD"],
        ["2015/11/19", 32, "DD"],
        ["2015/11/20", 26, "DD"],
    ]

themeriver=ThemeRiver()
themeriver.add(
            ["DQ", "TY", "SS", "QG", "SY", "DD"],
            data,
            singleaxis_opts=opts.SingleAxisOpts(type_="time", pos_bottom="10%"),
        )
themeriver.set_global_opts(title_opts=opts.TitleOpts(title="ThemeRiver-基本示例"))
themeriver.load_javascript()

# %%
themeriver.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="5259762de2354d2eba09a7ae8906190c" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_5259762de2354d2eba09a7ae8906190c = echarts.init(
#             document.getElementById('5259762de2354d2eba09a7ae8906190c'), 'white', {renderer: 'canvas'});
#         var option_5259762de2354d2eba09a7ae8906190c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "themeRiver",
#             "name": [
#                 "DQ",
#                 "TY",
#                 "SS",
#                 "QG",
#                 "SY",
#                 "DD"
#             ],
#             "data": [
#                 [
#                     "2015/11/08",
#                     10,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/09",
#                     15,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/10",
#                     35,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/14",
#                     7,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/15",
#                     2,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/16",
#                     17,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/17",
#                     33,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/18",
#                     40,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/19",
#                     32,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/20",
#                     26,
#                     "DQ"
#                 ],
#                 [
#                     "2015/11/08",
#                     35,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/09",
#                     36,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/10",
#                     37,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/11",
#                     22,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/12",
#                     24,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/13",
#                     26,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/14",
#                     34,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/15",
#                     21,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/16",
#                     18,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/17",
#                     45,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/18",
#                     32,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/19",
#                     35,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/20",
#                     30,
#                     "TY"
#                 ],
#                 [
#                     "2015/11/08",
#                     21,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/09",
#                     25,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/10",
#                     27,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/11",
#                     23,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/12",
#                     24,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/13",
#                     21,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/14",
#                     35,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/15",
#                     39,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/16",
#                     40,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/17",
#                     36,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/18",
#                     33,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/19",
#                     43,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/20",
#                     40,
#                     "SS"
#                 ],
#                 [
#                     "2015/11/14",
#                     7,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/15",
#                     2,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/16",
#                     17,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/17",
#                     33,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/18",
#                     40,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/19",
#                     32,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/20",
#                     26,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/21",
#                     35,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/22",
#                     40,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/23",
#                     32,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/24",
#                     26,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/25",
#                     22,
#                     "QG"
#                 ],
#                 [
#                     "2015/11/08",
#                     10,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/09",
#                     15,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/10",
#                     35,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/11",
#                     38,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/12",
#                     22,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/13",
#                     16,
#                     "SY"
#                 ],
#                 [
#                     "2015/11/14",
#                     7,
#                     "SY"

# %% [markdown]
# # 词云图

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType


words = [
    ("Sam S Club", 10000),
    ("Macys", 6181),
    ("Amy Schumer", 4386),
    ("Jurassic World", 4055),
    ("Charter Communications", 2467),
    ("Chick Fil A", 2244),
    ("Planet Fitness", 1868),
    ("Pitch Perfect", 1484),
    ("Express", 1112),
    ("Home", 865),
    ("Johnny Depp", 847),
    ("Lena Dunham", 582),
    ("Lewis Hamilton", 555),
    ("KXAN", 550),
    ("Mary Ellen Mark", 462),
    ("Farrah Abraham", 366),
    ("Rita Ora", 360),
    ("Serena Williams", 282),
    ("NCAA baseball tournament", 273),
    ("Point Break", 265),
]


world=WordCloud()
world.add("", words, word_size_range=[20, 100])
world.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
world.load_javascript()

# %%
world.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b11a71f2feec40e78ec557311656e5b2" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_b11a71f2feec40e78ec557311656e5b2 = echarts.init(
#             document.getElementById('b11a71f2feec40e78ec557311656e5b2'), 'white', {renderer: 'canvas'});
#         var option_b11a71f2feec40e78ec557311656e5b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,133,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Macys",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,93,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,82,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,134,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,116,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,157,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,159,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,131,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Express",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,121,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Home",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(85,37,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,42,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,31,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,109,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "KXAN",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,52,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,126,113)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,104,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,104,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,146,31)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,77,18)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Point Break",
#                     "value": 265,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,49,146)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "WordCloud-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_b11a71f2feec40e78ec557311656e5b2.se
